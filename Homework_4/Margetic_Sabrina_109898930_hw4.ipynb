# %% [markdown]
# # CSE527 Homework 4
# **Due date: 23:59 on April 24, 2021 (Sat.)**
#
# In this semester, we will use Google Colab for the assignments, which allows us to utilize resources that some of us might not have in their local machines such as GPUs. You will need to use your Stony Brook (*.stonybrook.edu) account for coding and Google Drive to save your results.
#
# ## Google Colab Tutorial
# ---
# Go to https://colab.research.google.com/notebooks/, you will see a tutorial named "Welcome to Colaboratory" file, where you can learn the basics of using google colab.
#
# Settings used for assignments: ***Edit -> Notebook Settings -> Runtime Type (Python 3)***.
#
#
# ## Description
# ---
# This project is an introduction to deep learning tools for computer vision. You will design and train deep convolutional networks for scene recognition using [PyTorch](http://pytorch.org). You can visualize the
# structure of the network with [mNeuron] (http://vision03.csail.mit.edu/cnn_art/index.html)
#
# In Problem 1 of the project you will train a deep convolutional network from scratch to recognize scenes. The starter codes gives you methods to load data and display them. You will need to define a simple network architecture and add jittering, normalization, and regularization to increase recognition accuracy to 50, 60, or perhaps 70%. Unfortunately, we only have 2,400 training examples so it doesn't seem possible to train a network from scratch which outperforms hand-crafted features
#
# For Problem 2 you will instead fine-tune a pre-trained deep network to achieve about 85% accuracy on the task. We will use the pretrained AlexNet network which was not trained to recognize scenes at all.
#
# These two approaches represent the most common approaches to recognition problems in computer vision today -- train a deep network from scratch if you have enough data (it's not always obvious whether or not you do), and if you cannot then instead fine-tune a pre-trained network.
#
# There are 2 problems in this homework with a total of 120 points including 20 bonus points. Be sure to read **Submission Guidelines** below. They are important. For the problems requiring text descriptions, you might want to add a markdown block for that.
#
# ## Dataset
# ---
# Save the [dataset(click me)](https://drive.google.com/open?id=1NWC3TMsXSWN2TeoYMCjhf2N1b-WRDh-M) into your working folder in your Google Drive for this homework. <br>
# Under your root folder, there should be a folder named "data" (i.e. XXX/Surname_Givenname_SBUID/data) containing the images.
# **Do not upload** the data subfolder before submitting on blackboard due to size limit. There should be only one .ipynb file under your root folder Surname_Givenname_SBUID.
#
# ## Some Tutorials (PyTorch)
# ---
# - You will be using PyTorch for deep learning toolbox (follow the [link](http://pytorch.org) for installation).
# - For PyTorch beginners, please read this [tutorial](http://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html) before doing your homework.
# - Feel free to study more tutorials at http://pytorch.org/tutorials/.
# - Find cool visualization here at http://playground.tensorflow.org.

# %%
# import packages here
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
import random 
import time

import torch
import torchvision
import torchvision.transforms as transforms

from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

# %%
# Mount your google drive where you've saved your assignment folder
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Set your working directory (in your google drive)
#   change it to your specific homework directory.
# %cd '/content/gdrive/My Drive/CSE527-21S-HW4'
# Out:
# /content/gdrive/My Drive/CSE527-21S-HW4

# %% [markdown]
# ## Problem 0: Loading and Preprocessing data
# ---
# (0 point) In this part, you are provided with a function that loads data into minibatches for training and testing in PyTorch. However, some preprocessing parts are missing. Your will need to implement them when doing Problem 1.

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------

def set_random_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     random.seed(seed)
     torch.backends.cudnn.deterministic = True
     #torch.backends.cudnn.deterministic = False
set_random_seed(11)

class_names = [name[13:] for name in glob.glob('./data/train/*')]
class_names = dict(zip(range(len(class_names)), class_names))
print("class_names: %s " % class_names)

def load_dataset(path, img_size, num_per_class=-1, batch_size=16, shuffle=False,
           augment=False, is_color=False, zero_centered=False):    
    data = []
    labels = []    
    channel_num = 3 if is_color else 1
        
    # read images and resizing
    for id, class_name in class_names.items():
        print("Loading images from class: %s" % id)
        img_path_class = glob.glob(path + class_name + '/*.jpg')
        if num_per_class > 0:
            img_path_class = img_path_class[:num_per_class]
        labels.extend([id]*len(img_path_class))
        for filename in img_path_class:
            if is_color:
                img = cv2.imread(filename)
            else:
                img = cv2.imread(filename, 0)
            
            # resize the image
            img = cv2.resize(img, img_size, cv2.INTER_LINEAR)
            
            if is_color:
                img = np.transpose(img, [2, 0, 1])
            
            # norm pixel values to [-1, 1]
            data.append(img.astype(np.float)/255*2-1)

    ##########--WRITE YOUR CODE HERE--##########
    # Data Augmentation 
    if augment: 
      rotated_list = []
      for i in range(0,len(data)):
        #rotate 180 degree
        rot = cv2.rotate(data[i], cv2.ROTATE_180)
        rotated_list.append(rot)

      data = data + rotated_list




    ##########-------END OF CODE-------##########    
    
    ##########--WRITE YOUR CODE HERE--##########
    # Data Normalization
    if zero_centered:
      #subtract mean based on channel number
      for i in range(0,len(data)):
        mean = np.mean(data[i])
        if(channel_num==3):
          mean =np.mean(data[i], axis=(0, 1)) #NEED TO DOUBLE CHECK
        data[i] = np.subtract(data[i],mean)



        
    ##########-------END OF CODE-------##########
         
    # randomly permute (this step is important for training)
    if shuffle:
        bundle = list(zip(data, labels))
        random.shuffle(bundle)
        data, labels = zip(*bundle)
    
    # divide data into minibatches of TorchTensors
    if batch_size > 1:
        batch_data = []
        batch_labels = []
         
        for i in range(int(len(data) / batch_size)):
            minibatch_d = data[i*batch_size: (i+1)*batch_size]
            minibatch_d = np.reshape(minibatch_d, (batch_size, channel_num, img_size[0], img_size[1]))
            batch_data.append(torch.from_numpy(minibatch_d))

            minibatch_l = labels[i*batch_size: (i+1)*batch_size]
            batch_labels.append(torch.LongTensor(minibatch_l))
        data, labels = batch_data, batch_labels 
    
    return zip(batch_data, batch_labels)
# Out:
# class_names: {0: 'Kitchen', 1: 'Store', 2: 'OpenCountry', 3: 'Office', 4: 'LivingRoom', 5: 'InsideCity', 6: 'Suburb', 7: 'TallBuilding', 8: 'Mountain', 9: 'Street', 10: 'Highway', 11: 'Bedroom', 12: 'Industrial', 13: 'Coast', 14: 'Forest', 15: 'Flower'}

# %%
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
# show some images
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if len(npimg.shape) > 2:
        npimg = np.transpose(img, [1, 2, 0])
    plt.figure
    plt.imshow(npimg, 'gray')
    plt.show()
img, label = trainloader_small[0][0][11][0], trainloader_small[0][1][11]
label = int(np.array(label))
print(class_names[label])
imshow(img)
# Out:
# Flower

# %% [markdown]
# ## Problem 1: Training a Network From Scratch
# Gone are the days of hand designed features. Now we have end-to-end learning in which a highly non-linear representation is learned for our data to maximize our objective function (in this case, 16-way classification accuracy). Let's start!

# %% [markdown]
# First, let's define a simpe network architecture.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  
           
      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4), 
      )
      
      self.classifier = nn.Sequential(
         nn.Linear(3600, 16), 
      )
      
    def forward(self, x):
      x = self.features(x)  
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %% [markdown]
# Then, let's define model training and evaluation functions.

# %%
#--------------------------------------------------
#       Model Training Function
#--------------------------------------------------
import torch.optim as optim
import time
  
def trainModel(net, trainloader, train_option, testloader=None):  
  loss_func = nn.CrossEntropyLoss()
  lr = train_option['lr']
  epoch = train_option['epoch']
  device = train_option['device'] if 'device' in train_option.keys() else 'cpu'
  log_iter = train_option['log_iter'] if 'log_iter' in train_option.keys() else 20
  eval_epoch = 1
  
  if 'optimizer' in train_option.keys():
    optimizer = train_option['optimizer']
  else:
    optimizer = optim.Adam(net.parameters(), lr=lr)

  start_time = time.time()
  if device == 'gpu':
    net = net.cuda()
    
  iters = 0
  running_loss = 0.0
  #output_train = []
  for ep in range(epoch):
    net.train()        
    for iter, (x, y) in enumerate(trainloader):
      iters += 1
      batch_x = Variable(x).float()
      batch_y = Variable(y).long()
      if device == 'gpu':
        batch_x = batch_x.cuda()
        batch_y = batch_y.cuda()

      outputs = net(batch_x)

      loss = loss_func(outputs, batch_y)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      running_loss += loss.item()
      
      time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))
      if iter % log_iter == 0:
        print('Epoch:{:2d} | Iter:{:5d} | Time: {} | Train Loss: {:.4f} | Average Loss: {:.4f} '.format(ep+1, iter, time_lapse, loss.item(), running_loss/iters))
   
    #output_test = [] #I ADDED
    if testloader is not None and ep % eval_epoch == 0:
      #output_test = evalModel(net, testloader)
      evalModel(net,testloader)
    #return output_train, output_test

# %%
#--------------------------------------------------
#       Model Evaluating Function
#--------------------------------------------------
import time
  
def evalModel(net, testloader): 
  acc = 0.0
  count = 0
  start_time = time.time()
  device = 'gpu' if next(net.parameters()).is_cuda else 'cpu'
  net.eval()
  
  #output_list = []
  for iter, (x, y) in enumerate(testloader):
        count += x.shape[0]
        batch_x = Variable(x).float()
        batch_y = Variable(y).long()
        if device == 'gpu':
          batch_x = batch_x.cuda()
          batch_y = batch_y.cuda()
        outputs = net(batch_x)
        acc += torch.sum(outputs.max(1)[1]==batch_y)
        
  time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))        
  print('Accuracy: {:5f} | Time: {}'.format(acc/count,time_lapse))
  #return output_list

# %% [markdown]
# Finally, let's start training and evaluation.

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet() 
train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 20
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)

# %% [markdown]
# Great! You would get around 0.45-0.50 accuracy by this very simple network. Now it's your job to beat this result.
#
# ### Problem 1.1
# (35 points) Try to boost the accuracy by doing the following steps:
#
# **Data Augmentation**: We don't have enough training data, let's augment the training data.
# If you **left-right flip (mirror) an image** of a scene, it never changes categories. A kitchen doesn't become a forest when mirrored. This isn't true in all domains — a "d" becomes a "b" when mirrored, so you can't "jitter" digit recognition training data in the same way. But we can synthetically increase our amount of training data by left-right mirroring training images during the learning process.
#
# After you implement mirroring, you should notice that your training error doesn't drop as quickly. That's actually a good thing, because it means the network isn't overfitting to the 2,400 original training images as much (because it sees 4,800 training images now, although they're not as good as 4,800 truly independent samples). Because the training and test errors fall more slowly, you may need more training epochs or you may try modifying the learning rate. You are **required** to implement mirroring as data augmentation for this part.
#
# You can try more elaborate forms of jittering -- zooming in a random amount, rotating a random amount, taking a random crop, etc. These are not required, you might want to try these in the bonus part.
#
# **Data Normalization**: The images aren't **zero-centered**. One simple trick which can help a lot is to subtract the mean from every image. It would arguably be more proper to only compute the mean from the training images (since the test/validation images should be strictly held out) but it won't make much of a difference. This part is **required**.
#
# **Network Regularization**: Add **dropout layer**. If you train your network (especially for more than the default 30 epochs) you'll see that the training error can decrease to zero while the val top1 error hovers at 40% to 50%. The network has learned weights which can perfectly recognize the training data, but those weights don't generalize to held out test data. The best regularization would be more training data but we don't have that. Instead we will use dropout regularization.
#
# What does dropout regularization do? It randomly turns off network connections at training time to fight overfitting. This prevents a unit in one layer from relying too strongly on a single unit in the previous layer. Dropout regularization can be interpreted as simultaneously training many "thinned" versions of your network. At test, all connections are restored which is analogous to taking an average prediction over all of the "thinned" networks. You can see a more complete discussion of dropout regularization in this [paper](https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf).
#
# The dropout layer has only one free parameter — the dropout rate — the proportion of connections that are randomly deleted. The default of 0.5 should be fine. Insert a dropout layer between your convolutional layers. In particular, insert it directly before your last convolutional layer (and try others if that helps). Your train accuracy should decrease much more slowly. That's to be expected — you're making life much harder for the training algorithm by cutting out connections randomly. In this part, you are **required** to add dropout layer to your network.
#
# **Please give detailed descriptions of your network layout in the following format:**<br>
# Data augmentation: [descriptions]<br>
# Data normalization: [descriptions]<br>
# Layer 1: [layer_type]: [Parameters]<br>
# Layer 2: [layer_type]: [Parameters]<br>
# ...<br>
# **Then report the final accuracy on test set.**
#
# The minimum accuracy required for this section is **0.55**.

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
set_random_seed(11)

class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  

      self.features = torch.nn.Sequential(
        nn.Conv2d(1,4,3),
        nn.ReLU(),
        nn.MaxPool2d(2, stride=2),
        nn.Conv2d(4,16,3),
        nn.ReLU(),
        nn.MaxPool2d(2,stride=2), 
        #nn.Dropout(.5),
        nn.Conv2d(16,64,3),
        nn.ReLU(),
        nn.MaxPool2d(2,stride=2),
        nn.Dropout(.5), 
        nn.Conv2d(64,128,3),
        nn.ReLU(),
        nn.MaxPool2d(2,stride=2), 
      )
      
      self.classifier = nn.Sequential(
        nn.Linear(128*2*2,16),
        #nn.Linear(128*2*2,128),
        #nn.Linear(128,64),
        #nn.Linear(64,16),
      )
      
      #dropout at rate =.5
      self.dropout = nn.Dropout(.5)

      
    def forward(self, x):
      x = self.features(x) 
      x = torch.flatten(x, 1)
      x=self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
mnet = TNet() 
train_option = {}
train_option['lr'] = 0.001
train_option['epoch'] = 117
train_option['device'] = 'gpu'
trainModel(mnet, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7739 | Average Loss: 2.7739
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.7749 | Average Loss: 2.7720
# Accuracy: 0.135417 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.6931 | Average Loss: 2.7568
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.6650 | Average Loss: 2.7199
# Accuracy: 0.226562 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.4174 | Average Loss: 2.6667
# Epoch: 3 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.6312 | Average Loss: 2.6120
# Accuracy: 0.270833 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.1528 | Average Loss: 2.5533
# Epoch: 4 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.5282 | Average Loss: 2.5022
# Accuracy: 0.309896 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.0389 | Average Loss: 2.4549
# Epoch: 5 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.4396 | Average Loss: 2.4083
# Accuracy: 0.335938 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.9310 | Average Loss: 2.3678
# Epoch: 6 | Iter:   20 | Time: 00:00:01 | Train Loss: 2.2820 | Average Loss: 2.3262
# Accuracy: 0.356771 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.8073 | Average Loss: 2.2901
# Epoch: 7 | Iter:   20 | Time: 00:00:01 | Train Loss: 2.1516 | Average Loss: 2.2505
# Accuracy: 0.361979 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.6944 | Average Loss: 2.2182
# Epoch: 8 | Iter:   20 | Time: 00:00:01 | Train Loss: 2.0142 | Average Loss: 2.1821
# Accuracy: 0.414062 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.6340 | Average Loss: 2.1529
# Epoch: 9 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.8713 | Average Loss: 2.1171
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.4613 | Average Loss: 2.0896
# Epoch:10 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.7877 | Average Loss: 2.0565
# Accuracy: 0.450521 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.3496 | Average Loss: 2.0299
# Epoch:11 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.7087 | Average Loss: 1.9982
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.2894 | Average Loss: 1.9729
# Epoch:12 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.7175 | Average Loss: 1.9441
# Accuracy: 0.479167 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.3153 | Average Loss: 1.9223
# Epoch:13 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.5490 | Average Loss: 1.8956
# Accuracy: 0.515625 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.1193 | Average Loss: 1.8743
# Epoch:14 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.5673 | Average Loss: 1.8496
# Accuracy: 0.513021 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.1763 | Average Loss: 1.8301
# Epoch:15 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.4416 | Average Loss: 1.8067
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.1011 | Average Loss: 1.7888
# Epoch:16 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.4409 | Average Loss: 1.7670
# Accuracy: 0.507812 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.0924 | Average Loss: 1.7507
# Epoch:17 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.4246 | Average Loss: 1.7313
# Accuracy: 0.539062 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.0322 | Average Loss: 1.7150
# Epoch:18 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.3049 | Average Loss: 1.6958
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.0177 | Average Loss: 1.6806
# Epoch:19 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.2872 | Average Loss: 1.6626
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.0843 | Average Loss: 1.6482
# Epoch:20 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.3224 | Average Loss: 1.6317
# Accuracy: 0.502604 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.0514 | Average Loss: 1.6185
# Epoch:21 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.3823 | Average Loss: 1.6031
# Accuracy: 0.518229 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.9361 | Average Loss: 1.5905
# Epoch:22 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.2629 | Average Loss: 1.5756
# Accuracy: 0.539062 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.9470 | Average Loss: 1.5631
# Epoch:23 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.1627 | Average Loss: 1.5486
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.9302 | Average Loss: 1.5369
# Epoch:24 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.1816 | Average Loss: 1.5226
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.8982 | Average Loss: 1.5113
# Epoch:25 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.0893 | Average Loss: 1.4979
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.7321 | Average Loss: 1.4866
# Epoch:26 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.0194 | Average Loss: 1.4737
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.7944 | Average Loss: 1.4630
# Epoch:27 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.0998 | Average Loss: 1.4502
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.7383 | Average Loss: 1.4392
# Epoch:28 | Iter:   20 | Time: 00:00:05 | Train Loss: 1.0899 | Average Loss: 1.4270
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.7433 | Average Loss: 1.4172
# Epoch:29 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.9528 | Average Loss: 1.4052
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6529 | Average Loss: 1.3952
# Epoch:30 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.8548 | Average Loss: 1.3835
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6803 | Average Loss: 1.3738
# Epoch:31 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.9455 | Average Loss: 1.3632
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.5302 | Average Loss: 1.3540
# Epoch:32 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.8256 | Average Loss: 1.3431
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6481 | Average Loss: 1.3344
# Epoch:33 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.8919 | Average Loss: 1.3237
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.5983 | Average Loss: 1.3152
# Epoch:34 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.9267 | Average Loss: 1.3053
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.5320 | Average Loss: 1.2969
# Epoch:35 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.9070 | Average Loss: 1.2873
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6099 | Average Loss: 1.2798
# Epoch:36 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.9791 | Average Loss: 1.2704
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.5597 | Average Loss: 1.2623
# Epoch:37 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.8853 | Average Loss: 1.2531
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6204 | Average Loss: 1.2456
# Epoch:38 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.8459 | Average Loss: 1.2364
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.4669 | Average Loss: 1.2287
# Epoch:39 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.8481 | Average Loss: 1.2202
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.4028 | Average Loss: 1.2128
# Epoch:40 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.7593 | Average Loss: 1.2042
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.5138 | Average Loss: 1.1968
# Epoch:41 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.7641 | Average Loss: 1.1882
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.5177 | Average Loss: 1.1811
# Epoch:42 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.6576 | Average Loss: 1.1724
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.5005 | Average Loss: 1.1655
# Epoch:43 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.7292 | Average Loss: 1.1573
# Accuracy: 0.497396 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.5816 | Average Loss: 1.1509
# Epoch:44 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.9005 | Average Loss: 1.1435
# Accuracy: 0.510417 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.3968 | Average Loss: 1.1372
# Epoch:45 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.8632 | Average Loss: 1.1302
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.4487 | Average Loss: 1.1243
# Epoch:46 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.9545 | Average Loss: 1.1181
# Accuracy: 0.505208 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.3975 | Average Loss: 1.1121
# Epoch:47 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.6361 | Average Loss: 1.1057
# Accuracy: 0.507812 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.3515 | Average Loss: 1.1001
# Epoch:48 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.5873 | Average Loss: 1.0933
# Accuracy: 0.520833 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.3756 | Average Loss: 1.0878
# Epoch:49 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.6712 | Average Loss: 1.0810
# Accuracy: 0.528646 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.4199 | Average Loss: 1.0752
# Epoch:50 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.6058 | Average Loss: 1.0689
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.3809 | Average Loss: 1.0631
# Epoch:51 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.5661 | Average Loss: 1.0565
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.3224 | Average Loss: 1.0513
# Epoch:52 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.6113 | Average Loss: 1.0453
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.4072 | Average Loss: 1.0399
# Epoch:53 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.5616 | Average Loss: 1.0338
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:54 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.3678 | Average Loss: 1.0286
# Epoch:54 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.3875 | Average Loss: 1.0224
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:55 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2349 | Average Loss: 1.0172
# Epoch:55 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.3797 | Average Loss: 1.0111
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:56 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3970 | Average Loss: 1.0061
# Epoch:56 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.4453 | Average Loss: 1.0002
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:57 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3092 | Average Loss: 0.9952
# Epoch:57 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.4799 | Average Loss: 0.9893
# Accuracy: 0.510417 | Time: 00:00:00
# Epoch:58 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2936 | Average Loss: 0.9845
# Epoch:58 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.4545 | Average Loss: 0.9784
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:59 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3797 | Average Loss: 0.9736
# Epoch:59 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.3117 | Average Loss: 0.9679
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:60 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3132 | Average Loss: 0.9631
# Epoch:60 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.4242 | Average Loss: 0.9575
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:61 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3082 | Average Loss: 0.9527
# Epoch:61 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.3966 | Average Loss: 0.9469
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:62 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3111 | Average Loss: 0.9421
# Epoch:62 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.2870 | Average Loss: 0.9363
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:63 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1840 | Average Loss: 0.9317
# Epoch:63 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.3514 | Average Loss: 0.9261
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:64 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2374 | Average Loss: 0.9215
# Epoch:64 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.2107 | Average Loss: 0.9159
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:65 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1891 | Average Loss: 0.9113
# Epoch:65 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.3376 | Average Loss: 0.9058
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:66 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2779 | Average Loss: 0.9014
# Epoch:66 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.3627 | Average Loss: 0.8962
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:67 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2676 | Average Loss: 0.8919
# Epoch:67 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.3050 | Average Loss: 0.8869
# Accuracy: 0.539062 | Time: 00:00:00
# Epoch:68 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.3145 | Average Loss: 0.8827
# Epoch:68 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.4632 | Average Loss: 0.8779
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:69 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2074 | Average Loss: 0.8736
# Epoch:69 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.3642 | Average Loss: 0.8688
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:70 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.3710 | Average Loss: 0.8649
# Epoch:70 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2283 | Average Loss: 0.8600
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:71 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2004 | Average Loss: 0.8561
# Epoch:71 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.3685 | Average Loss: 0.8515
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:72 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2706 | Average Loss: 0.8474
# Epoch:72 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2558 | Average Loss: 0.8426
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:73 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1298 | Average Loss: 0.8386
# Epoch:73 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2681 | Average Loss: 0.8339
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:74 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1149 | Average Loss: 0.8300
# Epoch:74 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.3034 | Average Loss: 0.8255
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:75 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2308 | Average Loss: 0.8217
# Epoch:75 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.2255 | Average Loss: 0.8172
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:76 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2060 | Average Loss: 0.8135
# Epoch:76 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.2487 | Average Loss: 0.8092
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:77 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1333 | Average Loss: 0.8055
# Epoch:77 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.2712 | Average Loss: 0.8013
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:78 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1536 | Average Loss: 0.7978
# Epoch:78 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.2230 | Average Loss: 0.7936
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:79 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2198 | Average Loss: 0.7901
# Epoch:79 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.2017 | Average Loss: 0.7862
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:80 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1315 | Average Loss: 0.7828
# Epoch:80 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.2546 | Average Loss: 0.7790
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:81 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2075 | Average Loss: 0.7759
# Epoch:81 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.4439 | Average Loss: 0.7722
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:82 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2486 | Average Loss: 0.7689
# Epoch:82 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1271 | Average Loss: 0.7649
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:83 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2204 | Average Loss: 0.7618
# Epoch:83 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.2439 | Average Loss: 0.7579
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:84 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1315 | Average Loss: 0.7548
# Epoch:84 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1806 | Average Loss: 0.7512
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:85 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1770 | Average Loss: 0.7483
# Epoch:85 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1738 | Average Loss: 0.7448
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:86 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0862 | Average Loss: 0.7416
# Epoch:86 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.3537 | Average Loss: 0.7380
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:87 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.2520 | Average Loss: 0.7351
# Epoch:87 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.2227 | Average Loss: 0.7316
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:88 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.2379 | Average Loss: 0.7286
# Epoch:88 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.3106 | Average Loss: 0.7252
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:89 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1752 | Average Loss: 0.7224
# Epoch:89 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.1747 | Average Loss: 0.7192
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:90 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.2025 | Average Loss: 0.7163
# Epoch:90 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.2762 | Average Loss: 0.7129
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:91 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1582 | Average Loss: 0.7102
# Epoch:91 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.2501 | Average Loss: 0.7070
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:92 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.1139 | Average Loss: 0.7044
# Epoch:92 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.1004 | Average Loss: 0.7014
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:93 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.1203 | Average Loss: 0.6987
# Epoch:93 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.2774 | Average Loss: 0.6956
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:94 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.1696 | Average Loss: 0.6931
# Epoch:94 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.1397 | Average Loss: 0.6901
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:95 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.2053 | Average Loss: 0.6875
# Epoch:95 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.2015 | Average Loss: 0.6845
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:96 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.1625 | Average Loss: 0.6819
# Epoch:96 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.2405 | Average Loss: 0.6790
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:97 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.1780 | Average Loss: 0.6766
# Epoch:97 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.2042 | Average Loss: 0.6737
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:98 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.1483 | Average Loss: 0.6713
# Epoch:98 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.2456 | Average Loss: 0.6686
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:99 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.1410 | Average Loss: 0.6663
# Epoch:99 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.1810 | Average Loss: 0.6638
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:100 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.0989 | Average Loss: 0.6614
# Epoch:100 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.2801 | Average Loss: 0.6587
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:101 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.2988 | Average Loss: 0.6567
# Epoch:101 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.2832 | Average Loss: 0.6540
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:102 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.1197 | Average Loss: 0.6518
# Epoch:102 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.0826 | Average Loss: 0.6491
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:103 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.2135 | Average Loss: 0.6469
# Epoch:103 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.2315 | Average Loss: 0.6443
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:104 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.2436 | Average Loss: 0.6423
# Epoch:104 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.1349 | Average Loss: 0.6398
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:105 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0686 | Average Loss: 0.6377
# Epoch:105 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.1355 | Average Loss: 0.6353
# Accuracy: 0.528646 | Time: 00:00:00
# Epoch:106 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0668 | Average Loss: 0.6331
# Epoch:106 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.1916 | Average Loss: 0.6307
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:107 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.1155 | Average Loss: 0.6287
# Epoch:107 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.2677 | Average Loss: 0.6264
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:108 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0736 | Average Loss: 0.6242
# Epoch:108 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.2535 | Average Loss: 0.6218
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:109 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.1486 | Average Loss: 0.6200
# Epoch:109 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.2495 | Average Loss: 0.6178
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:110 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.1003 | Average Loss: 0.6157
# Epoch:110 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.1824 | Average Loss: 0.6133
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:111 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0985 | Average Loss: 0.6116
# Epoch:111 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.2093 | Average Loss: 0.6094
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:112 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.1112 | Average Loss: 0.6076
# Epoch:112 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.2363 | Average Loss: 0.6055
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:113 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.1258 | Average Loss: 0.6037
# Epoch:113 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.1745 | Average Loss: 0.6017
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:114 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.1791 | Average Loss: 0.6000
# Epoch:114 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.1727 | Average Loss: 0.5980
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:115 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.1878 | Average Loss: 0.5962
# Epoch:115 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.1254 | Average Loss: 0.5943
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:116 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.1342 | Average Loss: 0.5926
# Epoch:116 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.1359 | Average Loss: 0.5905
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:117 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0565 | Average Loss: 0.5886
# Epoch:117 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.1224 | Average Loss: 0.5866
# Accuracy: 0.549479 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Data augmentation: Rotated images by 180 degrees.
#
# Data normalization: Made mean equal to zero. Implemented in load_dataset() funciton.
#
# Layer 1: Convolution Layer with ReLU activation function.
#
# Layer 2: Max pooling done at every 2 by 2 increment.
#
# Layer 3: Convolution Layer with ReLU activation function.
#
# Layer 4: Max pooling done at every 2 by 2 increment.
#
# Layer 5: Probability of dropout = .5 for Convolution Layer with ReLU activation function.
#
# Layer 6: Linear Function.
#
# Layer 7: Linear Function.
#
# Layer 8: Linear Function.
#
#
# Accuray on test set: 0.585938

# %% [markdown]
# ## Problem 1.2
#
# (15 points) Try **three different techniques** taught in the class to increase the accuracy of your model. Such as increasing training data by randomly rotating training images, adding batch normalization, different activation functions (e.g., sigmoid) and model architecture modification. Note that too many layers can do you no good due to insufficient training data. Clearly describe your method and accuracy increase/decrease for each of the three techniques.
#
# The minimum accuracy required for this section is **0.60**. (At least one Technique should achieve this)
#
# ### Technique 1

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  

      self.features = torch.nn.Sequential(
        nn.Conv2d(1,4,3),
        nn.ReLU(),
        #nn.Sigmoid(),
        nn.MaxPool2d(2, stride=2),
        nn.Conv2d(4,16,3),
        nn.ReLU(),
        #nn.Sigmoid(),
        nn.MaxPool2d(2,stride=2), 
        #nn.Dropout(.5),
        nn.Conv2d(16,64,3),
        nn.ReLU(),
        #nn.Sigmoid(),
        nn.MaxPool2d(2,stride=2),
        nn.Dropout(.5), 
        nn.Conv2d(64,128,3),
        nn.ReLU(),
        #nn.Sigmoid(),
        nn.MaxPool2d(2,stride=2), 
        #nn.MaxPool2d(4,stride=4), 
        #nn.Conv2d(128, 64, 3),
        #nn.Conv2d(128,360,3),
        #nn.ReLU(),
        #nn.Sigmoid(),
        #nn.MaxPool2d(2,stride=2), 
      )
      
      self.classifier = nn.Sequential(
        #nn.Linear(128*1*1, 64),
        nn.Linear(128*2*2,128),
        #nn.Sigmoid(),
        #nn.ReLU(),
        #nn.Linear(64,16),
        #nn.ReLU(),
        #nn.Linear(64,16),
        nn.Linear(128,64),
        #nn.ReLU(),
        #nn.Sigmoid(),
        nn.Linear(64,16),
      )
      
      #dropout at rate =.5
      self.dropout = nn.Dropout(.5)

      
    def forward(self, x):
      #print(x)
      #print(x.shape)
      x = self.features(x) 
      #x = self.features(x) 
      #print(x.shape)
      x = torch.flatten(x, 1)
      x=self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
mnet = TNet() 
train_option = {}
train_option['lr'] = 0.001
train_option['epoch'] = 200
train_option['device'] = 'gpu'
trainModel(mnet, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7884 | Average Loss: 2.7884
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.7541 | Average Loss: 2.7704
# Accuracy: 0.138021 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.6725 | Average Loss: 2.7506
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.5191 | Average Loss: 2.6830
# Accuracy: 0.200521 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.4782 | Average Loss: 2.6118
# Epoch: 3 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.2820 | Average Loss: 2.5425
# Accuracy: 0.226562 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.3969 | Average Loss: 2.4893
# Epoch: 4 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.1338 | Average Loss: 2.4339
# Accuracy: 0.273438 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.2173 | Average Loss: 2.3932
# Epoch: 5 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.9672 | Average Loss: 2.3419
# Accuracy: 0.278646 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.0819 | Average Loss: 2.3056
# Epoch: 6 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.8689 | Average Loss: 2.2641
# Accuracy: 0.289062 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.9670 | Average Loss: 2.2353
# Epoch: 7 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.9349 | Average Loss: 2.1993
# Accuracy: 0.338542 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.9153 | Average Loss: 2.1735
# Epoch: 8 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.8149 | Average Loss: 2.1419
# Accuracy: 0.341146 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.8274 | Average Loss: 2.1169
# Epoch: 9 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.7752 | Average Loss: 2.0870
# Accuracy: 0.375000 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.7842 | Average Loss: 2.0654
# Epoch:10 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.8101 | Average Loss: 2.0394
# Accuracy: 0.377604 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.7085 | Average Loss: 2.0182
# Epoch:11 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.6420 | Average Loss: 1.9930
# Accuracy: 0.385417 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.6745 | Average Loss: 1.9731
# Epoch:12 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.6093 | Average Loss: 1.9483
# Accuracy: 0.393229 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.5752 | Average Loss: 1.9298
# Epoch:13 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.4490 | Average Loss: 1.9055
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.5194 | Average Loss: 1.8889
# Epoch:14 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.4932 | Average Loss: 1.8669
# Accuracy: 0.377604 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.5281 | Average Loss: 1.8503
# Epoch:15 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.3906 | Average Loss: 1.8313
# Accuracy: 0.447917 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.2861 | Average Loss: 1.8162
# Epoch:16 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.4150 | Average Loss: 1.7980
# Accuracy: 0.440104 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.2411 | Average Loss: 1.7837
# Epoch:17 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.3485 | Average Loss: 1.7665
# Accuracy: 0.453125 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.1861 | Average Loss: 1.7527
# Epoch:18 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.2574 | Average Loss: 1.7351
# Accuracy: 0.466146 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.9288 | Average Loss: 1.7209
# Epoch:19 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.2268 | Average Loss: 1.7054
# Accuracy: 0.463542 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.1359 | Average Loss: 1.6917
# Epoch:20 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.1126 | Average Loss: 1.6757
# Accuracy: 0.473958 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.0096 | Average Loss: 1.6614
# Epoch:21 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.1465 | Average Loss: 1.6465
# Accuracy: 0.476562 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.9269 | Average Loss: 1.6331
# Epoch:22 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.1757 | Average Loss: 1.6192
# Accuracy: 0.486979 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.0413 | Average Loss: 1.6066
# Epoch:23 | Iter:   20 | Time: 00:00:03 | Train Loss: 1.0752 | Average Loss: 1.5926
# Accuracy: 0.492188 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.8566 | Average Loss: 1.5805
# Epoch:24 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.9581 | Average Loss: 1.5663
# Accuracy: 0.494792 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.8591 | Average Loss: 1.5540
# Epoch:25 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.9812 | Average Loss: 1.5397
# Accuracy: 0.494792 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.8440 | Average Loss: 1.5273
# Epoch:26 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.8921 | Average Loss: 1.5135
# Accuracy: 0.505208 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.7641 | Average Loss: 1.5016
# Epoch:27 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.9225 | Average Loss: 1.4882
# Accuracy: 0.494792 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.7245 | Average Loss: 1.4770
# Epoch:28 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.7946 | Average Loss: 1.4630
# Accuracy: 0.489583 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.7352 | Average Loss: 1.4517
# Epoch:29 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.7264 | Average Loss: 1.4384
# Accuracy: 0.518229 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6810 | Average Loss: 1.4278
# Epoch:30 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.7003 | Average Loss: 1.4139
# Accuracy: 0.513021 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.7119 | Average Loss: 1.4031
# Epoch:31 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.6972 | Average Loss: 1.3904
# Accuracy: 0.502604 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.5491 | Average Loss: 1.3800
# Epoch:32 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.7280 | Average Loss: 1.3675
# Accuracy: 0.492188 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6952 | Average Loss: 1.3575
# Epoch:33 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.5973 | Average Loss: 1.3453
# Accuracy: 0.513021 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.5529 | Average Loss: 1.3350
# Epoch:34 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.7733 | Average Loss: 1.3231
# Accuracy: 0.528646 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.4725 | Average Loss: 1.3134
# Epoch:35 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.5866 | Average Loss: 1.3030
# Accuracy: 0.528646 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.4619 | Average Loss: 1.2939
# Epoch:36 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.4949 | Average Loss: 1.2830
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.5432 | Average Loss: 1.2738
# Epoch:37 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.5953 | Average Loss: 1.2628
# Accuracy: 0.513021 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.4534 | Average Loss: 1.2544
# Epoch:38 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.5436 | Average Loss: 1.2439
# Accuracy: 0.505208 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.5539 | Average Loss: 1.2353
# Epoch:39 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.6149 | Average Loss: 1.2254
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.4555 | Average Loss: 1.2168
# Epoch:40 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.4825 | Average Loss: 1.2066
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.5333 | Average Loss: 1.1991
# Epoch:41 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.3670 | Average Loss: 1.1891
# Accuracy: 0.507812 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.5752 | Average Loss: 1.1815
# Epoch:42 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.5597 | Average Loss: 1.1725
# Accuracy: 0.494792 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.7376 | Average Loss: 1.1654
# Epoch:43 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.4528 | Average Loss: 1.1565
# Accuracy: 0.518229 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.4363 | Average Loss: 1.1493
# Epoch:44 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.5226 | Average Loss: 1.1413
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.5601 | Average Loss: 1.1339
# Epoch:45 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.4794 | Average Loss: 1.1256
# Accuracy: 0.507812 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.5421 | Average Loss: 1.1189
# Epoch:46 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.4920 | Average Loss: 1.1103
# Accuracy: 0.507812 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.4368 | Average Loss: 1.1034
# Epoch:47 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.4144 | Average Loss: 1.0949
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.4071 | Average Loss: 1.0882
# Epoch:48 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.3614 | Average Loss: 1.0800
# Accuracy: 0.518229 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.4582 | Average Loss: 1.0734
# Epoch:49 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.5064 | Average Loss: 1.0658
# Accuracy: 0.526042 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.3906 | Average Loss: 1.0594
# Epoch:50 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.2876 | Average Loss: 1.0517
# Accuracy: 0.497396 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.5169 | Average Loss: 1.0457
# Epoch:51 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.4069 | Average Loss: 1.0387
# Accuracy: 0.520833 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.3476 | Average Loss: 1.0326
# Epoch:52 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.5631 | Average Loss: 1.0254
# Accuracy: 0.520833 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.4596 | Average Loss: 1.0192
# Epoch:53 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.3200 | Average Loss: 1.0122
# Accuracy: 0.526042 | Time: 00:00:00
# Epoch:54 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.2615 | Average Loss: 1.0065
# Epoch:54 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.4407 | Average Loss: 0.9997
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:55 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.4098 | Average Loss: 0.9945
# Epoch:55 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.2284 | Average Loss: 0.9879
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:56 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.4442 | Average Loss: 0.9827
# Epoch:56 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.2758 | Average Loss: 0.9763
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:57 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.2884 | Average Loss: 0.9707
# Epoch:57 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.3157 | Average Loss: 0.9647
# Accuracy: 0.515625 | Time: 00:00:00
# Epoch:58 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.1828 | Average Loss: 0.9592
# Epoch:58 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.2563 | Average Loss: 0.9529
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:59 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.2950 | Average Loss: 0.9476
# Epoch:59 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.2481 | Average Loss: 0.9416
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:60 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.2498 | Average Loss: 0.9362
# Epoch:60 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.2319 | Average Loss: 0.9302
# Accuracy: 0.528646 | Time: 00:00:00
# Epoch:61 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.1376 | Average Loss: 0.9251
# Epoch:61 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.2490 | Average Loss: 0.9194
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:62 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3226 | Average Loss: 0.9146
# Epoch:62 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1786 | Average Loss: 0.9090
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:63 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.1711 | Average Loss: 0.9049
# Epoch:63 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1457 | Average Loss: 0.8995
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:64 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.1572 | Average Loss: 0.8949
# Epoch:64 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1540 | Average Loss: 0.8895
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:65 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2716 | Average Loss: 0.8847
# Epoch:65 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.2825 | Average Loss: 0.8793
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:66 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3242 | Average Loss: 0.8753
# Epoch:66 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.3153 | Average Loss: 0.8700
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:67 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.1973 | Average Loss: 0.8661
# Epoch:67 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.2752 | Average Loss: 0.8610
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:68 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1852 | Average Loss: 0.8569
# Epoch:68 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.2285 | Average Loss: 0.8520
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:69 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2106 | Average Loss: 0.8481
# Epoch:69 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.3808 | Average Loss: 0.8430
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:70 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1626 | Average Loss: 0.8386
# Epoch:70 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.2406 | Average Loss: 0.8335
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:71 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2766 | Average Loss: 0.8295
# Epoch:71 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.0566 | Average Loss: 0.8246
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:72 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3203 | Average Loss: 0.8205
# Epoch:72 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.1338 | Average Loss: 0.8158
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:73 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1694 | Average Loss: 0.8119
# Epoch:73 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.3477 | Average Loss: 0.8074
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:74 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2211 | Average Loss: 0.8036
# Epoch:74 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.1703 | Average Loss: 0.7991
# Accuracy: 0.510417 | Time: 00:00:00
# Epoch:75 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2441 | Average Loss: 0.7954
# Epoch:75 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.3201 | Average Loss: 0.7910
# Accuracy: 0.523438 | Time: 00:00:00
# Epoch:76 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1769 | Average Loss: 0.7873
# Epoch:76 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.2120 | Average Loss: 0.7830
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:77 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2247 | Average Loss: 0.7795
# Epoch:77 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.3118 | Average Loss: 0.7750
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:78 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1770 | Average Loss: 0.7714
# Epoch:78 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.1611 | Average Loss: 0.7671
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:79 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1137 | Average Loss: 0.7636
# Epoch:79 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2087 | Average Loss: 0.7595
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:80 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1600 | Average Loss: 0.7560
# Epoch:80 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1555 | Average Loss: 0.7521
# Accuracy: 0.518229 | Time: 00:00:00
# Epoch:81 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2794 | Average Loss: 0.7489
# Epoch:81 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2563 | Average Loss: 0.7450
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:82 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2679 | Average Loss: 0.7418
# Epoch:82 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.2682 | Average Loss: 0.7382
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:83 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1469 | Average Loss: 0.7349
# Epoch:83 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1270 | Average Loss: 0.7310
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:84 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2240 | Average Loss: 0.7279
# Epoch:84 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.3443 | Average Loss: 0.7245
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:85 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.0800 | Average Loss: 0.7215
# Epoch:85 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1755 | Average Loss: 0.7180
# Accuracy: 0.523438 | Time: 00:00:00
# Epoch:86 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1778 | Average Loss: 0.7153
# Epoch:86 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.1921 | Average Loss: 0.7118
# Accuracy: 0.513021 | Time: 00:00:00
# Epoch:87 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.3100 | Average Loss: 0.7091
# Epoch:87 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.2159 | Average Loss: 0.7059
# Accuracy: 0.513021 | Time: 00:00:00
# Epoch:88 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.4422 | Average Loss: 0.7033
# Epoch:88 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.0725 | Average Loss: 0.6998
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:89 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1048 | Average Loss: 0.6970
# Epoch:89 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.1168 | Average Loss: 0.6938
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:90 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1531 | Average Loss: 0.6913
# Epoch:90 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.2462 | Average Loss: 0.6883
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:91 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2304 | Average Loss: 0.6857
# Epoch:91 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.2647 | Average Loss: 0.6829
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:92 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1236 | Average Loss: 0.6802
# Epoch:92 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.2152 | Average Loss: 0.6773
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:93 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2430 | Average Loss: 0.6747
# Epoch:93 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1859 | Average Loss: 0.6718
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:94 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1284 | Average Loss: 0.6692
# Epoch:94 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1151 | Average Loss: 0.6663
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:95 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1788 | Average Loss: 0.6637
# Epoch:95 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1358 | Average Loss: 0.6606
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:96 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1258 | Average Loss: 0.6579
# Epoch:96 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1157 | Average Loss: 0.6550
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:97 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0986 | Average Loss: 0.6526
# Epoch:97 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.0856 | Average Loss: 0.6500
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:98 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1460 | Average Loss: 0.6476
# Epoch:98 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0880 | Average Loss: 0.6448
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:99 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0625 | Average Loss: 0.6424
# Epoch:99 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0994 | Average Loss: 0.6395
# Accuracy: 0.539062 | Time: 00:00:00
# Epoch:100 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.2535 | Average Loss: 0.6372
# Epoch:100 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0537 | Average Loss: 0.6345
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:101 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0627 | Average Loss: 0.6321
# Epoch:101 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.2157 | Average Loss: 0.6294
# Accuracy: 0.539062 | Time: 00:00:00
# Epoch:102 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1747 | Average Loss: 0.6272
# Epoch:102 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.1097 | Average Loss: 0.6247
# Accuracy: 0.528646 | Time: 00:00:00
# Epoch:103 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1510 | Average Loss: 0.6226
# Epoch:103 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.1048 | Average Loss: 0.6199
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:104 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.1906 | Average Loss: 0.6176
# Epoch:104 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0641 | Average Loss: 0.6149
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:105 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.0665 | Average Loss: 0.6127
# Epoch:105 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0449 | Average Loss: 0.6103
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:106 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.0672 | Average Loss: 0.6081
# Epoch:106 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.1840 | Average Loss: 0.6055
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:107 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.2108 | Average Loss: 0.6033
# Epoch:107 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.3175 | Average Loss: 0.6009
# Accuracy: 0.523438 | Time: 00:00:00
# Epoch:108 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.1277 | Average Loss: 0.5991
# Epoch:108 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.2585 | Average Loss: 0.5968
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:109 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.2074 | Average Loss: 0.5949
# Epoch:109 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.1584 | Average Loss: 0.5925
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:110 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.0734 | Average Loss: 0.5906
# Epoch:110 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.0845 | Average Loss: 0.5882
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:111 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.1177 | Average Loss: 0.5862
# Epoch:111 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.0700 | Average Loss: 0.5841
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:112 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.0626 | Average Loss: 0.5822
# Epoch:112 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.2614 | Average Loss: 0.5801
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:113 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.1866 | Average Loss: 0.5782
# Epoch:113 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.1209 | Average Loss: 0.5760
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:114 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.1029 | Average Loss: 0.5742
# Epoch:114 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.0325 | Average Loss: 0.5719
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:115 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.0794 | Average Loss: 0.5700
# Epoch:115 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.1414 | Average Loss: 0.5679
# Accuracy: 0.539062 | Time: 00:00:00
# Epoch:116 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0614 | Average Loss: 0.5660
# Epoch:116 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.0728 | Average Loss: 0.5638
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:117 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0583 | Average Loss: 0.5619
# Epoch:117 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.1915 | Average Loss: 0.5597
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:118 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0642 | Average Loss: 0.5581
# Epoch:118 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.2546 | Average Loss: 0.5562
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:119 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0423 | Average Loss: 0.5545
# Epoch:119 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.1123 | Average Loss: 0.5525
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:120 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.1346 | Average Loss: 0.5508
# Epoch:120 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.2446 | Average Loss: 0.5489
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:121 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0843 | Average Loss: 0.5471
# Epoch:121 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.1231 | Average Loss: 0.5451
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:122 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0493 | Average Loss: 0.5434
# Epoch:122 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0428 | Average Loss: 0.5416
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:123 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.2156 | Average Loss: 0.5400
# Epoch:123 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0836 | Average Loss: 0.5380
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:124 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0669 | Average Loss: 0.5365
# Epoch:124 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0344 | Average Loss: 0.5345
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:125 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.1328 | Average Loss: 0.5330
# Epoch:125 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0922 | Average Loss: 0.5311
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:126 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.1641 | Average Loss: 0.5296
# Epoch:126 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.2096 | Average Loss: 0.5278
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:127 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0933 | Average Loss: 0.5262
# Epoch:127 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0196 | Average Loss: 0.5245
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:128 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.1387 | Average Loss: 0.5230
# Epoch:128 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.2184 | Average Loss: 0.5212
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:129 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0870 | Average Loss: 0.5197
# Epoch:129 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0920 | Average Loss: 0.5180
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:130 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0845 | Average Loss: 0.5165
# Epoch:130 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.1886 | Average Loss: 0.5149
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:131 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.1094 | Average Loss: 0.5135
# Epoch:131 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0717 | Average Loss: 0.5119
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:132 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0353 | Average Loss: 0.5105
# Epoch:132 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0658 | Average Loss: 0.5087
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:133 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.1151 | Average Loss: 0.5073
# Epoch:133 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.2283 | Average Loss: 0.5056
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:134 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0508 | Average Loss: 0.5042
# Epoch:134 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0700 | Average Loss: 0.5026
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:135 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.2292 | Average Loss: 0.5012
# Epoch:135 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0149 | Average Loss: 0.4996
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:136 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0493 | Average Loss: 0.4983
# Epoch:136 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.1971 | Average Loss: 0.4967
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:137 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.1456 | Average Loss: 0.4953
# Epoch:137 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0939 | Average Loss: 0.4937
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:138 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0770 | Average Loss: 0.4923
# Epoch:138 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0451 | Average Loss: 0.4907
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:139 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0844 | Average Loss: 0.4894
# Epoch:139 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.1398 | Average Loss: 0.4878
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:140 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0562 | Average Loss: 0.4865
# Epoch:140 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0946 | Average Loss: 0.4850
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:141 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0838 | Average Loss: 0.4837
# Epoch:141 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.1484 | Average Loss: 0.4822
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:142 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.1104 | Average Loss: 0.4810
# Epoch:142 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.2197 | Average Loss: 0.4797
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:143 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.1606 | Average Loss: 0.4784
# Epoch:143 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0688 | Average Loss: 0.4769
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:144 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0410 | Average Loss: 0.4757
# Epoch:144 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.1138 | Average Loss: 0.4743
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:145 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.1884 | Average Loss: 0.4732
# Epoch:145 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0834 | Average Loss: 0.4718
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:146 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.0744 | Average Loss: 0.4707
# Epoch:146 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.1223 | Average Loss: 0.4692
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:147 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.1360 | Average Loss: 0.4681
# Epoch:147 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.0268 | Average Loss: 0.4667
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:148 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.0504 | Average Loss: 0.4655
# Epoch:148 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.1920 | Average Loss: 0.4642
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:149 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.0576 | Average Loss: 0.4631
# Epoch:149 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.2451 | Average Loss: 0.4619
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:150 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.1540 | Average Loss: 0.4609
# Epoch:150 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.1240 | Average Loss: 0.4595
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:151 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.1464 | Average Loss: 0.4584
# Epoch:151 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.0987 | Average Loss: 0.4570
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:152 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0595 | Average Loss: 0.4559
# Epoch:152 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.0739 | Average Loss: 0.4545
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:153 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0813 | Average Loss: 0.4534
# Epoch:153 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.2102 | Average Loss: 0.4521
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:154 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0403 | Average Loss: 0.4510
# Epoch:154 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.2408 | Average Loss: 0.4499
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:155 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0997 | Average Loss: 0.4489
# Epoch:155 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.1616 | Average Loss: 0.4477
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:156 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0496 | Average Loss: 0.4467
# Epoch:156 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.0844 | Average Loss: 0.4455
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:157 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0152 | Average Loss: 0.4444
# Epoch:157 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.1281 | Average Loss: 0.4433
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:158 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.1735 | Average Loss: 0.4423
# Epoch:158 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.0726 | Average Loss: 0.4411
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:159 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.2202 | Average Loss: 0.4402
# Epoch:159 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.0227 | Average Loss: 0.4390
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:160 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.0648 | Average Loss: 0.4379
# Epoch:160 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.0647 | Average Loss: 0.4368
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:161 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.1579 | Average Loss: 0.4359
# Epoch:161 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.1809 | Average Loss: 0.4348
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:162 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.1502 | Average Loss: 0.4339
# Epoch:162 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.0837 | Average Loss: 0.4328
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:163 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.1246 | Average Loss: 0.4319
# Epoch:163 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.0873 | Average Loss: 0.4307
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:164 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0593 | Average Loss: 0.4298
# Epoch:164 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.0274 | Average Loss: 0.4286
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:165 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0493 | Average Loss: 0.4277
# Epoch:165 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.0605 | Average Loss: 0.4266
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:166 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0755 | Average Loss: 0.4256
# Epoch:166 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.0756 | Average Loss: 0.4245
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:167 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0211 | Average Loss: 0.4235
# Epoch:167 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.0605 | Average Loss: 0.4224
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:168 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0807 | Average Loss: 0.4214
# Epoch:168 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.1441 | Average Loss: 0.4203
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:169 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0429 | Average Loss: 0.4194
# Epoch:169 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.0793 | Average Loss: 0.4182
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:170 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0545 | Average Loss: 0.4173
# Epoch:170 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.1211 | Average Loss: 0.4165
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:171 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0392 | Average Loss: 0.4157
# Epoch:171 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.1169 | Average Loss: 0.4146
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:172 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0378 | Average Loss: 0.4137
# Epoch:172 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.2095 | Average Loss: 0.4127
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:173 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.2435 | Average Loss: 0.4120
# Epoch:173 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.0883 | Average Loss: 0.4110
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:174 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.1793 | Average Loss: 0.4102
# Epoch:174 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.1519 | Average Loss: 0.4092
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:175 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0133 | Average Loss: 0.4083
# Epoch:175 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.0572 | Average Loss: 0.4073
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:176 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0938 | Average Loss: 0.4064
# Epoch:176 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.1454 | Average Loss: 0.4054
# Accuracy: 0.539062 | Time: 00:00:00
# Epoch:177 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.0811 | Average Loss: 0.4045
# Epoch:177 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.0769 | Average Loss: 0.4036
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:178 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.1437 | Average Loss: 0.4029
# Epoch:178 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.1256 | Average Loss: 0.4020
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:179 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.0668 | Average Loss: 0.4012
# Epoch:179 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.0802 | Average Loss: 0.4002
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:180 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.1035 | Average Loss: 0.3993
# Epoch:180 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.0172 | Average Loss: 0.3984
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:181 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.0456 | Average Loss: 0.3975
# Epoch:181 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.1277 | Average Loss: 0.3966
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:182 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.3337 | Average Loss: 0.3959
# Epoch:182 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.1438 | Average Loss: 0.3950
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:183 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.1098 | Average Loss: 0.3942
# Epoch:183 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.0438 | Average Loss: 0.3933
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:184 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0994 | Average Loss: 0.3926
# Epoch:184 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.0218 | Average Loss: 0.3917
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:185 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.1146 | Average Loss: 0.3910
# Epoch:185 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.0632 | Average Loss: 0.3901
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:186 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0731 | Average Loss: 0.3894
# Epoch:186 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.1295 | Average Loss: 0.3885
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:187 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0532 | Average Loss: 0.3877
# Epoch:187 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.1311 | Average Loss: 0.3868
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:188 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0641 | Average Loss: 0.3861
# Epoch:188 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.2151 | Average Loss: 0.3852
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:189 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.1244 | Average Loss: 0.3845
# Epoch:189 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.0331 | Average Loss: 0.3836
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:190 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.0117 | Average Loss: 0.3828
# Epoch:190 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.1469 | Average Loss: 0.3820
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:191 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.1418 | Average Loss: 0.3813
# Epoch:191 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.0391 | Average Loss: 0.3805
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:192 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.1219 | Average Loss: 0.3798
# Epoch:192 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.0158 | Average Loss: 0.3790
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:193 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.1186 | Average Loss: 0.3783
# Epoch:193 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.0184 | Average Loss: 0.3775
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:194 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.0105 | Average Loss: 0.3767
# Epoch:194 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.1058 | Average Loss: 0.3759
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:195 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0324 | Average Loss: 0.3751
# Epoch:195 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0448 | Average Loss: 0.3743
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:196 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0050 | Average Loss: 0.3736
# Epoch:196 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0112 | Average Loss: 0.3728
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:197 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0191 | Average Loss: 0.3720
# Epoch:197 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0834 | Average Loss: 0.3711
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:198 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0093 | Average Loss: 0.3704
# Epoch:198 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0249 | Average Loss: 0.3695
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:199 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0754 | Average Loss: 0.3689
# Epoch:199 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0461 | Average Loss: 0.3680
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:200 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0384 | Average Loss: 0.3674
# Epoch:200 | Iter:   20 | Time: 00:00:33 | Train Loss: 0.0809 | Average Loss: 0.3666
# Accuracy: 0.531250 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Technique 1: Change in Network Architecture - More Fully Connected Layers.
#
# Accuracy on test set: .609375
#
# Accuracy increases/decreases: .023437

# %% [markdown]
# ### Technique 2

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  

      self.features = torch.nn.Sequential(
        nn.Conv2d(1,4,3),
        nn.BatchNorm2d(4), #WITH RELU??
        nn.ReLU(),
        nn.MaxPool2d(2, stride=2),
        nn.Conv2d(4,16,3),
        nn.BatchNorm2d(16), #WITH RELU??
        nn.ReLU(),
        nn.MaxPool2d(2,stride=2), 
        #nn.Dropout(.5),
        nn.Conv2d(16,64,3),
        nn.BatchNorm2d(64), #WITH RELU??
        nn.ReLU(),
        nn.MaxPool2d(2,stride=2),
        nn.Dropout(.5), 
        nn.Conv2d(64,128,3),
        nn.BatchNorm2d(128), #WITH RELU??
        nn.ReLU(),
        nn.MaxPool2d(2,stride=2), 
      )
      
      self.classifier = nn.Sequential(
        nn.Linear(128*2*2,16),
        #nn.Linear(128*2*2,128),
        #nn.Linear(128,64),
        #nn.Linear(64,16),
      )
      
      #dropout at rate =.5
      self.dropout = nn.Dropout(.5)

      
    def forward(self, x):
      #print(x)
      #print(x.shape)
      x = self.features(x) 
      #x = self.features(x) 
      #print(x.shape)
      x = torch.flatten(x, 1)
      x=self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
mnet = TNet() 
train_option = {}
train_option['lr'] = 0.001
train_option['epoch'] = 120
train_option['device'] = 'gpu'
trainModel(mnet, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.0544 | Average Loss: 3.0544
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.4384 | Average Loss: 2.6110
# Accuracy: 0.187500 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.1840 | Average Loss: 2.4654
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.1190 | Average Loss: 2.3227
# Accuracy: 0.351562 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.8048 | Average Loss: 2.2219
# Epoch: 3 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.8071 | Average Loss: 2.1164
# Accuracy: 0.403646 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.5453 | Average Loss: 2.0365
# Epoch: 4 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.6284 | Average Loss: 1.9573
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.4166 | Average Loss: 1.8980
# Epoch: 5 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.5030 | Average Loss: 1.8350
# Accuracy: 0.466146 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2206 | Average Loss: 1.7864
# Epoch: 6 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.3654 | Average Loss: 1.7330
# Accuracy: 0.502604 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2635 | Average Loss: 1.6922
# Epoch: 7 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.3449 | Average Loss: 1.6478
# Accuracy: 0.526042 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.0962 | Average Loss: 1.6125
# Epoch: 8 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.2156 | Average Loss: 1.5740
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.9669 | Average Loss: 1.5425
# Epoch: 9 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.2170 | Average Loss: 1.5091
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.9096 | Average Loss: 1.4833
# Epoch:10 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.2286 | Average Loss: 1.4542
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.8727 | Average Loss: 1.4304
# Epoch:11 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.1245 | Average Loss: 1.4023
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.8308 | Average Loss: 1.3791
# Epoch:12 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.0519 | Average Loss: 1.3544
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.8001 | Average Loss: 1.3335
# Epoch:13 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.1013 | Average Loss: 1.3105
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.7319 | Average Loss: 1.2918
# Epoch:14 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.9470 | Average Loss: 1.2701
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.8479 | Average Loss: 1.2538
# Epoch:15 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.7920 | Average Loss: 1.2345
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.7042 | Average Loss: 1.2180
# Epoch:16 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.8462 | Average Loss: 1.1992
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6009 | Average Loss: 1.1845
# Epoch:17 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.9136 | Average Loss: 1.1681
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.7029 | Average Loss: 1.1542
# Epoch:18 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.7548 | Average Loss: 1.1373
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.5499 | Average Loss: 1.1238
# Epoch:19 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.8207 | Average Loss: 1.1079
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.5971 | Average Loss: 1.0947
# Epoch:20 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.7330 | Average Loss: 1.0798
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.5019 | Average Loss: 1.0678
# Epoch:21 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.5899 | Average Loss: 1.0535
# Accuracy: 0.598958 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.5075 | Average Loss: 1.0417
# Epoch:22 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.5104 | Average Loss: 1.0283
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.5018 | Average Loss: 1.0175
# Epoch:23 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.5581 | Average Loss: 1.0044
# Accuracy: 0.604167 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.3821 | Average Loss: 0.9939
# Epoch:24 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.5270 | Average Loss: 0.9813
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.4596 | Average Loss: 0.9708
# Epoch:25 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.4784 | Average Loss: 0.9587
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.3990 | Average Loss: 0.9487
# Epoch:26 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.4940 | Average Loss: 0.9372
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.3261 | Average Loss: 0.9283
# Epoch:27 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.5635 | Average Loss: 0.9174
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.4013 | Average Loss: 0.9084
# Epoch:28 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.5343 | Average Loss: 0.8981
# Accuracy: 0.611979 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.2869 | Average Loss: 0.8893
# Epoch:29 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.4582 | Average Loss: 0.8792
# Accuracy: 0.598958 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.3281 | Average Loss: 0.8708
# Epoch:30 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.5158 | Average Loss: 0.8616
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.3391 | Average Loss: 0.8537
# Epoch:31 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.4004 | Average Loss: 0.8445
# Accuracy: 0.614583 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.3231 | Average Loss: 0.8366
# Epoch:32 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.5329 | Average Loss: 0.8278
# Accuracy: 0.619792 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.2126 | Average Loss: 0.8199
# Epoch:33 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.3485 | Average Loss: 0.8110
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.2450 | Average Loss: 0.8036
# Epoch:34 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.3424 | Average Loss: 0.7952
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.2304 | Average Loss: 0.7881
# Epoch:35 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.3501 | Average Loss: 0.7798
# Accuracy: 0.611979 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.2234 | Average Loss: 0.7728
# Epoch:36 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2740 | Average Loss: 0.7651
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.2015 | Average Loss: 0.7586
# Epoch:37 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2700 | Average Loss: 0.7513
# Accuracy: 0.604167 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.1726 | Average Loss: 0.7450
# Epoch:38 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.3838 | Average Loss: 0.7377
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.1894 | Average Loss: 0.7316
# Epoch:39 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2859 | Average Loss: 0.7245
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.1652 | Average Loss: 0.7185
# Epoch:40 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2511 | Average Loss: 0.7118
# Accuracy: 0.617188 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.1667 | Average Loss: 0.7062
# Epoch:41 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2226 | Average Loss: 0.6993
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.2321 | Average Loss: 0.6939
# Epoch:42 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.2585 | Average Loss: 0.6875
# Accuracy: 0.611979 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.1999 | Average Loss: 0.6821
# Epoch:43 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.2613 | Average Loss: 0.6757
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.1595 | Average Loss: 0.6705
# Epoch:44 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.2308 | Average Loss: 0.6646
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.1818 | Average Loss: 0.6596
# Epoch:45 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.2073 | Average Loss: 0.6539
# Accuracy: 0.611979 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.1729 | Average Loss: 0.6491
# Epoch:46 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.1926 | Average Loss: 0.6436
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.1430 | Average Loss: 0.6390
# Epoch:47 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.1792 | Average Loss: 0.6336
# Accuracy: 0.617188 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0620 | Average Loss: 0.6289
# Epoch:48 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.1957 | Average Loss: 0.6238
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.1548 | Average Loss: 0.6195
# Epoch:49 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.2158 | Average Loss: 0.6145
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.1849 | Average Loss: 0.6102
# Epoch:50 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.2165 | Average Loss: 0.6052
# Accuracy: 0.604167 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.1732 | Average Loss: 0.6010
# Epoch:51 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1363 | Average Loss: 0.5962
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.1563 | Average Loss: 0.5922
# Epoch:52 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1509 | Average Loss: 0.5875
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.1298 | Average Loss: 0.5836
# Epoch:53 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.2130 | Average Loss: 0.5791
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:54 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.1021 | Average Loss: 0.5752
# Epoch:54 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1606 | Average Loss: 0.5708
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:55 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0826 | Average Loss: 0.5673
# Epoch:55 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1684 | Average Loss: 0.5632
# Accuracy: 0.611979 | Time: 00:00:00
# Epoch:56 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0854 | Average Loss: 0.5596
# Epoch:56 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.2125 | Average Loss: 0.5554
# Accuracy: 0.614583 | Time: 00:00:00
# Epoch:57 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.0889 | Average Loss: 0.5518
# Epoch:57 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.1373 | Average Loss: 0.5477
# Accuracy: 0.627604 | Time: 00:00:00
# Epoch:58 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1392 | Average Loss: 0.5443
# Epoch:58 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.1118 | Average Loss: 0.5403
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:59 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.0863 | Average Loss: 0.5370
# Epoch:59 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.0789 | Average Loss: 0.5332
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:60 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1172 | Average Loss: 0.5299
# Epoch:60 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.1186 | Average Loss: 0.5261
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:61 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1159 | Average Loss: 0.5230
# Epoch:61 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.0952 | Average Loss: 0.5193
# Accuracy: 0.627604 | Time: 00:00:00
# Epoch:62 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1558 | Average Loss: 0.5162
# Epoch:62 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.1575 | Average Loss: 0.5130
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:63 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.0731 | Average Loss: 0.5100
# Epoch:63 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.1676 | Average Loss: 0.5067
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:64 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1083 | Average Loss: 0.5038
# Epoch:64 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.0991 | Average Loss: 0.5004
# Accuracy: 0.611979 | Time: 00:00:00
# Epoch:65 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1304 | Average Loss: 0.4976
# Epoch:65 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.0643 | Average Loss: 0.4943
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:66 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.0716 | Average Loss: 0.4915
# Epoch:66 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1107 | Average Loss: 0.4883
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:67 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1415 | Average Loss: 0.4857
# Epoch:67 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1385 | Average Loss: 0.4827
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:68 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1590 | Average Loss: 0.4800
# Epoch:68 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1272 | Average Loss: 0.4769
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:69 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1243 | Average Loss: 0.4745
# Epoch:69 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.0959 | Average Loss: 0.4715
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:70 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.0572 | Average Loss: 0.4691
# Epoch:70 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1147 | Average Loss: 0.4662
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch:71 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.0976 | Average Loss: 0.4638
# Epoch:71 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.0892 | Average Loss: 0.4609
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:72 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1154 | Average Loss: 0.4586
# Epoch:72 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.0918 | Average Loss: 0.4559
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:73 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1134 | Average Loss: 0.4535
# Epoch:73 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.0901 | Average Loss: 0.4509
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:74 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.0557 | Average Loss: 0.4487
# Epoch:74 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.0743 | Average Loss: 0.4460
# Accuracy: 0.645833 | Time: 00:00:00
# Epoch:75 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.0794 | Average Loss: 0.4438
# Epoch:75 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.1586 | Average Loss: 0.4413
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:76 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1234 | Average Loss: 0.4392
# Epoch:76 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.0918 | Average Loss: 0.4368
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:77 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0595 | Average Loss: 0.4347
# Epoch:77 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.0762 | Average Loss: 0.4323
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:78 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1526 | Average Loss: 0.4302
# Epoch:78 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1411 | Average Loss: 0.4279
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:79 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0970 | Average Loss: 0.4259
# Epoch:79 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.0669 | Average Loss: 0.4235
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:80 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1148 | Average Loss: 0.4215
# Epoch:80 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1062 | Average Loss: 0.4191
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:81 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0478 | Average Loss: 0.4171
# Epoch:81 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.0418 | Average Loss: 0.4148
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:82 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1337 | Average Loss: 0.4129
# Epoch:82 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0864 | Average Loss: 0.4105
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:83 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1002 | Average Loss: 0.4086
# Epoch:83 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0510 | Average Loss: 0.4065
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:84 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1178 | Average Loss: 0.4047
# Epoch:84 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0520 | Average Loss: 0.4026
# Accuracy: 0.638021 | Time: 00:00:00
# Epoch:85 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0647 | Average Loss: 0.4009
# Epoch:85 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.1389 | Average Loss: 0.3989
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:86 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0466 | Average Loss: 0.3972
# Epoch:86 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0714 | Average Loss: 0.3951
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:87 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.0444 | Average Loss: 0.3933
# Epoch:87 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.1278 | Average Loss: 0.3913
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:88 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.0554 | Average Loss: 0.3896
# Epoch:88 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0217 | Average Loss: 0.3876
# Accuracy: 0.614583 | Time: 00:00:00
# Epoch:89 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.0764 | Average Loss: 0.3859
# Epoch:89 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0803 | Average Loss: 0.3839
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:90 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.0806 | Average Loss: 0.3823
# Epoch:90 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0664 | Average Loss: 0.3804
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:91 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.0443 | Average Loss: 0.3788
# Epoch:91 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0970 | Average Loss: 0.3770
# Accuracy: 0.604167 | Time: 00:00:00
# Epoch:92 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.0822 | Average Loss: 0.3755
# Epoch:92 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.0395 | Average Loss: 0.3736
# Accuracy: 0.640625 | Time: 00:00:00
# Epoch:93 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.1058 | Average Loss: 0.3721
# Epoch:93 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.1636 | Average Loss: 0.3704
# Accuracy: 0.609375 | Time: 00:00:00
# Epoch:94 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.0431 | Average Loss: 0.3689
# Epoch:94 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.0888 | Average Loss: 0.3672
# Accuracy: 0.627604 | Time: 00:00:00
# Epoch:95 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.1286 | Average Loss: 0.3657
# Epoch:95 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.1145 | Average Loss: 0.3640
# Accuracy: 0.606771 | Time: 00:00:00
# Epoch:96 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.0610 | Average Loss: 0.3626
# Epoch:96 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.0642 | Average Loss: 0.3609
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:97 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0343 | Average Loss: 0.3595
# Epoch:97 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.1219 | Average Loss: 0.3580
# Accuracy: 0.640625 | Time: 00:00:00
# Epoch:98 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0994 | Average Loss: 0.3566
# Epoch:98 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.0780 | Average Loss: 0.3550
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch:99 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.1032 | Average Loss: 0.3537
# Epoch:99 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.0221 | Average Loss: 0.3521
# Accuracy: 0.614583 | Time: 00:00:00
# Epoch:100 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0852 | Average Loss: 0.3508
# Epoch:100 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.0985 | Average Loss: 0.3493
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:101 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.1166 | Average Loss: 0.3480
# Epoch:101 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.0512 | Average Loss: 0.3464
# Accuracy: 0.611979 | Time: 00:00:00
# Epoch:102 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0518 | Average Loss: 0.3451
# Epoch:102 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0412 | Average Loss: 0.3436
# Accuracy: 0.614583 | Time: 00:00:00
# Epoch:103 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0957 | Average Loss: 0.3423
# Epoch:103 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0537 | Average Loss: 0.3408
# Accuracy: 0.619792 | Time: 00:00:00
# Epoch:104 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0166 | Average Loss: 0.3395
# Epoch:104 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0337 | Average Loss: 0.3380
# Accuracy: 0.614583 | Time: 00:00:00
# Epoch:105 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.1095 | Average Loss: 0.3368
# Epoch:105 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0638 | Average Loss: 0.3354
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:106 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0782 | Average Loss: 0.3342
# Epoch:106 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0175 | Average Loss: 0.3328
# Accuracy: 0.627604 | Time: 00:00:00
# Epoch:107 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0354 | Average Loss: 0.3316
# Epoch:107 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0610 | Average Loss: 0.3302
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:108 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0298 | Average Loss: 0.3290
# Epoch:108 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0630 | Average Loss: 0.3275
# Accuracy: 0.664062 | Time: 00:00:00
# Epoch:109 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0392 | Average Loss: 0.3262
# Epoch:109 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.1225 | Average Loss: 0.3250
# Accuracy: 0.614583 | Time: 00:00:00
# Epoch:110 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0904 | Average Loss: 0.3239
# Epoch:110 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.1082 | Average Loss: 0.3226
# Accuracy: 0.630208 | Time: 00:00:00
# Epoch:111 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0475 | Average Loss: 0.3214
# Epoch:111 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0517 | Average Loss: 0.3202
# Accuracy: 0.598958 | Time: 00:00:00
# Epoch:112 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.1024 | Average Loss: 0.3191
# Epoch:112 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0859 | Average Loss: 0.3178
# Accuracy: 0.648438 | Time: 00:00:00
# Epoch:113 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0232 | Average Loss: 0.3167
# Epoch:113 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0937 | Average Loss: 0.3154
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:114 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0494 | Average Loss: 0.3144
# Epoch:114 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0330 | Average Loss: 0.3131
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:115 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0463 | Average Loss: 0.3121
# Epoch:115 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0594 | Average Loss: 0.3109
# Accuracy: 0.635417 | Time: 00:00:00
# Epoch:116 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0667 | Average Loss: 0.3098
# Epoch:116 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0379 | Average Loss: 0.3086
# Accuracy: 0.604167 | Time: 00:00:00
# Epoch:117 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0358 | Average Loss: 0.3075
# Epoch:117 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0521 | Average Loss: 0.3064
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:118 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0994 | Average Loss: 0.3054
# Epoch:118 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0197 | Average Loss: 0.3043
# Accuracy: 0.643229 | Time: 00:00:00
# Epoch:119 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0370 | Average Loss: 0.3033
# Epoch:119 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0270 | Average Loss: 0.3021
# Accuracy: 0.614583 | Time: 00:00:00
# Epoch:120 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0443 | Average Loss: 0.3012
# Epoch:120 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0437 | Average Loss: 0.3000
# Accuracy: 0.617188 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Technique 2: Batch Normalization
#
# Accuracy on test set: .617188
#
# Accuracy increases/decreases: .03125

# %% [markdown]
# ### Technique 3

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 64 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()  

      self.features = torch.nn.Sequential(
        nn.Conv2d(1,4,3),
        nn.ReLU(),
        nn.MaxPool2d(2, stride=2),
        nn.Conv2d(4,16,3),
        nn.ReLU(),
        nn.MaxPool2d(2,stride=2), 
        nn.Conv2d(16,64,3),
        nn.Tanh(),
        nn.MaxPool2d(2,stride=2),
        nn.Dropout(.5), 
        nn.Conv2d(64,128,3),
        nn.Tanh(),
        nn.MaxPool2d(2,stride=2), 
      )
      
      self.classifier = nn.Sequential(
        nn.Linear(128*2*2,16),
        #nn.Linear(128*2*2,128),
        #nn.Linear(128,64),
        #nn.Linear(64,16),
      )
      
      #dropout at rate =.5
      self.dropout = nn.Dropout(.5)

      
    def forward(self, x):
      #print(x)
      #print(x.shape)
      x = self.features(x) 
      #x = self.features(x) 
      #print(x.shape)
      x = torch.flatten(x, 1)
      x=self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
mnet = TNet() 
train_option = {}
train_option['lr'] = 0.001
train_option['epoch'] = 300
train_option['device'] = 'gpu'
trainModel(mnet, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7694 | Average Loss: 2.7694
# Epoch: 1 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.7763 | Average Loss: 2.7696
# Accuracy: 0.164062 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.6629 | Average Loss: 2.7249
# Epoch: 2 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.4965 | Average Loss: 2.6466
# Accuracy: 0.244792 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.4501 | Average Loss: 2.5796
# Epoch: 3 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.3103 | Average Loss: 2.5111
# Accuracy: 0.291667 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.3399 | Average Loss: 2.4553
# Epoch: 4 | Iter:   20 | Time: 00:00:00 | Train Loss: 2.1120 | Average Loss: 2.4012
# Accuracy: 0.294271 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.1768 | Average Loss: 2.3525
# Epoch: 5 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.8762 | Average Loss: 2.3017
# Accuracy: 0.356771 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.0373 | Average Loss: 2.2545
# Epoch: 6 | Iter:   20 | Time: 00:00:00 | Train Loss: 1.7051 | Average Loss: 2.2067
# Accuracy: 0.401042 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.8449 | Average Loss: 2.1627
# Epoch: 7 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.5360 | Average Loss: 2.1192
# Accuracy: 0.424479 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.7694 | Average Loss: 2.0800
# Epoch: 8 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.4944 | Average Loss: 2.0419
# Accuracy: 0.442708 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.7005 | Average Loss: 2.0080
# Epoch: 9 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.4218 | Average Loss: 1.9725
# Accuracy: 0.471354 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.6091 | Average Loss: 1.9426
# Epoch:10 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.2768 | Average Loss: 1.9105
# Accuracy: 0.481771 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.5198 | Average Loss: 1.8828
# Epoch:11 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.2190 | Average Loss: 1.8535
# Accuracy: 0.494792 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.4228 | Average Loss: 1.8282
# Epoch:12 | Iter:   20 | Time: 00:00:01 | Train Loss: 1.1522 | Average Loss: 1.8010
# Accuracy: 0.497396 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.4036 | Average Loss: 1.7779
# Epoch:13 | Iter:   20 | Time: 00:00:02 | Train Loss: 1.0227 | Average Loss: 1.7531
# Accuracy: 0.510417 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.4339 | Average Loss: 1.7321
# Epoch:14 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.9619 | Average Loss: 1.7085
# Accuracy: 0.497396 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.3005 | Average Loss: 1.6882
# Epoch:15 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.9350 | Average Loss: 1.6673
# Accuracy: 0.523438 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.1573 | Average Loss: 1.6481
# Epoch:16 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.9302 | Average Loss: 1.6278
# Accuracy: 0.539062 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.1732 | Average Loss: 1.6097
# Epoch:17 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.8499 | Average Loss: 1.5903
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.0490 | Average Loss: 1.5730
# Epoch:18 | Iter:   20 | Time: 00:00:02 | Train Loss: 0.8013 | Average Loss: 1.5544
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.0784 | Average Loss: 1.5383
# Epoch:19 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.8034 | Average Loss: 1.5204
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.9959 | Average Loss: 1.5051
# Epoch:20 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.7392 | Average Loss: 1.4883
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.9353 | Average Loss: 1.4737
# Epoch:21 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.7641 | Average Loss: 1.4578
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.9264 | Average Loss: 1.4440
# Epoch:22 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.7201 | Average Loss: 1.4287
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.8643 | Average Loss: 1.4149
# Epoch:23 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.7423 | Average Loss: 1.4000
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.8588 | Average Loss: 1.3871
# Epoch:24 | Iter:   20 | Time: 00:00:03 | Train Loss: 0.6295 | Average Loss: 1.3732
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.8741 | Average Loss: 1.3602
# Epoch:25 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.6067 | Average Loss: 1.3461
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.7900 | Average Loss: 1.3340
# Epoch:26 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.5717 | Average Loss: 1.3201
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.7671 | Average Loss: 1.3085
# Epoch:27 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.5453 | Average Loss: 1.2953
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.7666 | Average Loss: 1.2840
# Epoch:28 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.5428 | Average Loss: 1.2714
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6407 | Average Loss: 1.2605
# Epoch:29 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.5354 | Average Loss: 1.2480
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6072 | Average Loss: 1.2373
# Epoch:30 | Iter:   20 | Time: 00:00:04 | Train Loss: 0.5419 | Average Loss: 1.2250
# Accuracy: 0.598958 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6247 | Average Loss: 1.2148
# Epoch:31 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.4707 | Average Loss: 1.2027
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.5809 | Average Loss: 1.1926
# Epoch:32 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.4377 | Average Loss: 1.1808
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.5842 | Average Loss: 1.1709
# Epoch:33 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.3678 | Average Loss: 1.1596
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6490 | Average Loss: 1.1503
# Epoch:34 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.4160 | Average Loss: 1.1393
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.5393 | Average Loss: 1.1298
# Epoch:35 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.3857 | Average Loss: 1.1190
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.5591 | Average Loss: 1.1100
# Epoch:36 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.3985 | Average Loss: 1.0998
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.4342 | Average Loss: 1.0912
# Epoch:37 | Iter:   20 | Time: 00:00:05 | Train Loss: 0.3468 | Average Loss: 1.0814
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.4088 | Average Loss: 1.0729
# Epoch:38 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.3509 | Average Loss: 1.0632
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.4582 | Average Loss: 1.0550
# Epoch:39 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.2795 | Average Loss: 1.0454
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.4323 | Average Loss: 1.0373
# Epoch:40 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.3121 | Average Loss: 1.0278
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.4843 | Average Loss: 1.0198
# Epoch:41 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.2799 | Average Loss: 1.0107
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.3574 | Average Loss: 1.0032
# Epoch:42 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.3163 | Average Loss: 0.9945
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.3785 | Average Loss: 0.9870
# Epoch:43 | Iter:   20 | Time: 00:00:06 | Train Loss: 0.2121 | Average Loss: 0.9783
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.3890 | Average Loss: 0.9713
# Epoch:44 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2631 | Average Loss: 0.9628
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.3448 | Average Loss: 0.9559
# Epoch:45 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2348 | Average Loss: 0.9480
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.3783 | Average Loss: 0.9413
# Epoch:46 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2356 | Average Loss: 0.9334
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.3536 | Average Loss: 0.9270
# Epoch:47 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2436 | Average Loss: 0.9193
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.3178 | Average Loss: 0.9129
# Epoch:48 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.1745 | Average Loss: 0.9054
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.2342 | Average Loss: 0.8992
# Epoch:49 | Iter:   20 | Time: 00:00:07 | Train Loss: 0.2422 | Average Loss: 0.8919
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.2759 | Average Loss: 0.8858
# Epoch:50 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.2405 | Average Loss: 0.8787
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.3430 | Average Loss: 0.8729
# Epoch:51 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.2975 | Average Loss: 0.8662
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.2831 | Average Loss: 0.8605
# Epoch:52 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.2033 | Average Loss: 0.8538
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.3842 | Average Loss: 0.8483
# Epoch:53 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.2314 | Average Loss: 0.8420
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:54 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.3250 | Average Loss: 0.8366
# Epoch:54 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.1725 | Average Loss: 0.8305
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:55 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.2641 | Average Loss: 0.8253
# Epoch:55 | Iter:   20 | Time: 00:00:08 | Train Loss: 0.1842 | Average Loss: 0.8193
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:56 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.1759 | Average Loss: 0.8142
# Epoch:56 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.1688 | Average Loss: 0.8083
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:57 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.2226 | Average Loss: 0.8032
# Epoch:57 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.1514 | Average Loss: 0.7975
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:58 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.1739 | Average Loss: 0.7927
# Epoch:58 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.2211 | Average Loss: 0.7871
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:59 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.4391 | Average Loss: 0.7825
# Epoch:59 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.1436 | Average Loss: 0.7770
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:60 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.1750 | Average Loss: 0.7722
# Epoch:60 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.1706 | Average Loss: 0.7670
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:61 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.1754 | Average Loss: 0.7625
# Epoch:61 | Iter:   20 | Time: 00:00:09 | Train Loss: 0.1844 | Average Loss: 0.7574
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:62 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.2465 | Average Loss: 0.7531
# Epoch:62 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.0911 | Average Loss: 0.7482
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:63 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2860 | Average Loss: 0.7441
# Epoch:63 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.2098 | Average Loss: 0.7392
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:64 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2033 | Average Loss: 0.7350
# Epoch:64 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1400 | Average Loss: 0.7303
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:65 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.1530 | Average Loss: 0.7262
# Epoch:65 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1377 | Average Loss: 0.7214
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:66 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.1980 | Average Loss: 0.7175
# Epoch:66 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1188 | Average Loss: 0.7129
# Accuracy: 0.526042 | Time: 00:00:00
# Epoch:67 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.1851 | Average Loss: 0.7090
# Epoch:67 | Iter:   20 | Time: 00:00:10 | Train Loss: 0.1644 | Average Loss: 0.7045
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:68 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.1409 | Average Loss: 0.7007
# Epoch:68 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.1359 | Average Loss: 0.6963
# Accuracy: 0.533854 | Time: 00:00:00
# Epoch:69 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1520 | Average Loss: 0.6926
# Epoch:69 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.1694 | Average Loss: 0.6883
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:70 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1266 | Average Loss: 0.6848
# Epoch:70 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.1836 | Average Loss: 0.6807
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:71 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1667 | Average Loss: 0.6773
# Epoch:71 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.1461 | Average Loss: 0.6733
# Accuracy: 0.523438 | Time: 00:00:00
# Epoch:72 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1210 | Average Loss: 0.6699
# Epoch:72 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.1659 | Average Loss: 0.6660
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:73 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1195 | Average Loss: 0.6626
# Epoch:73 | Iter:   20 | Time: 00:00:11 | Train Loss: 0.1064 | Average Loss: 0.6586
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:74 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1739 | Average Loss: 0.6551
# Epoch:74 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.1472 | Average Loss: 0.6512
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:75 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1621 | Average Loss: 0.6479
# Epoch:75 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.1353 | Average Loss: 0.6441
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:76 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1532 | Average Loss: 0.6409
# Epoch:76 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.1007 | Average Loss: 0.6372
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:77 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1304 | Average Loss: 0.6340
# Epoch:77 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.1551 | Average Loss: 0.6304
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:78 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1209 | Average Loss: 0.6273
# Epoch:78 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.1304 | Average Loss: 0.6237
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:79 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.0669 | Average Loss: 0.6207
# Epoch:79 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.0800 | Average Loss: 0.6171
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:80 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1187 | Average Loss: 0.6142
# Epoch:80 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1074 | Average Loss: 0.6108
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:81 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.0966 | Average Loss: 0.6079
# Epoch:81 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1148 | Average Loss: 0.6045
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:82 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.0867 | Average Loss: 0.6016
# Epoch:82 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1230 | Average Loss: 0.5983
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:83 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.0910 | Average Loss: 0.5955
# Epoch:83 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1009 | Average Loss: 0.5922
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:84 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1517 | Average Loss: 0.5895
# Epoch:84 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1046 | Average Loss: 0.5863
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:85 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.0952 | Average Loss: 0.5836
# Epoch:85 | Iter:   20 | Time: 00:00:13 | Train Loss: 0.1148 | Average Loss: 0.5804
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:86 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1494 | Average Loss: 0.5778
# Epoch:86 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.0772 | Average Loss: 0.5748
# Accuracy: 0.604167 | Time: 00:00:00
# Epoch:87 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.0737 | Average Loss: 0.5722
# Epoch:87 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.0858 | Average Loss: 0.5692
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:88 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.0959 | Average Loss: 0.5666
# Epoch:88 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.1323 | Average Loss: 0.5637
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:89 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1173 | Average Loss: 0.5611
# Epoch:89 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.1247 | Average Loss: 0.5582
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:90 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.0781 | Average Loss: 0.5558
# Epoch:90 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.0748 | Average Loss: 0.5529
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:91 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.0685 | Average Loss: 0.5505
# Epoch:91 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.0877 | Average Loss: 0.5477
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:92 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.0825 | Average Loss: 0.5453
# Epoch:92 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.0572 | Average Loss: 0.5425
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:93 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0787 | Average Loss: 0.5402
# Epoch:93 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.0525 | Average Loss: 0.5375
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:94 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1850 | Average Loss: 0.5352
# Epoch:94 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.0457 | Average Loss: 0.5326
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:95 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0761 | Average Loss: 0.5304
# Epoch:95 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.1203 | Average Loss: 0.5278
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:96 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0963 | Average Loss: 0.5256
# Epoch:96 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.0462 | Average Loss: 0.5231
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:97 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1063 | Average Loss: 0.5210
# Epoch:97 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.0616 | Average Loss: 0.5184
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:98 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0586 | Average Loss: 0.5163
# Epoch:98 | Iter:   20 | Time: 00:00:15 | Train Loss: 0.0835 | Average Loss: 0.5138
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:99 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0899 | Average Loss: 0.5118
# Epoch:99 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0560 | Average Loss: 0.5093
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:100 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0969 | Average Loss: 0.5073
# Epoch:100 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.1152 | Average Loss: 0.5050
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:101 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0746 | Average Loss: 0.5030
# Epoch:101 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0920 | Average Loss: 0.5006
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:102 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0607 | Average Loss: 0.4987
# Epoch:102 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0668 | Average Loss: 0.4963
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:103 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0551 | Average Loss: 0.4945
# Epoch:103 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0676 | Average Loss: 0.4922
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:104 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0830 | Average Loss: 0.4903
# Epoch:104 | Iter:   20 | Time: 00:00:16 | Train Loss: 0.0615 | Average Loss: 0.4882
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:105 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.0603 | Average Loss: 0.4862
# Epoch:105 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0328 | Average Loss: 0.4841
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:106 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.0582 | Average Loss: 0.4822
# Epoch:106 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0399 | Average Loss: 0.4800
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:107 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.0738 | Average Loss: 0.4782
# Epoch:107 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0424 | Average Loss: 0.4761
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:108 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.0880 | Average Loss: 0.4744
# Epoch:108 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0815 | Average Loss: 0.4723
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:109 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.1010 | Average Loss: 0.4705
# Epoch:109 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0419 | Average Loss: 0.4686
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:110 | Iter:    0 | Time: 00:00:17 | Train Loss: 0.1231 | Average Loss: 0.4669
# Epoch:110 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.0614 | Average Loss: 0.4650
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:111 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.0781 | Average Loss: 0.4633
# Epoch:111 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.0565 | Average Loss: 0.4613
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:112 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.0950 | Average Loss: 0.4597
# Epoch:112 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.0526 | Average Loss: 0.4577
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:113 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.0741 | Average Loss: 0.4561
# Epoch:113 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.0626 | Average Loss: 0.4542
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:114 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.0832 | Average Loss: 0.4526
# Epoch:114 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.1220 | Average Loss: 0.4508
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:115 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.1062 | Average Loss: 0.4492
# Epoch:115 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.0990 | Average Loss: 0.4474
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:116 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.0784 | Average Loss: 0.4459
# Epoch:116 | Iter:   20 | Time: 00:00:18 | Train Loss: 0.0652 | Average Loss: 0.4441
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:117 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0718 | Average Loss: 0.4426
# Epoch:117 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.0445 | Average Loss: 0.4409
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:118 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0860 | Average Loss: 0.4394
# Epoch:118 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.1157 | Average Loss: 0.4377
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:119 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0572 | Average Loss: 0.4362
# Epoch:119 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.0480 | Average Loss: 0.4345
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:120 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0506 | Average Loss: 0.4331
# Epoch:120 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.0262 | Average Loss: 0.4314
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:121 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0471 | Average Loss: 0.4300
# Epoch:121 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.0313 | Average Loss: 0.4283
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:122 | Iter:    0 | Time: 00:00:19 | Train Loss: 0.0729 | Average Loss: 0.4269
# Epoch:122 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.0715 | Average Loss: 0.4253
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:123 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0601 | Average Loss: 0.4240
# Epoch:123 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.1036 | Average Loss: 0.4223
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:124 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0949 | Average Loss: 0.4210
# Epoch:124 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0559 | Average Loss: 0.4196
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:125 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0467 | Average Loss: 0.4182
# Epoch:125 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0735 | Average Loss: 0.4167
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:126 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0887 | Average Loss: 0.4154
# Epoch:126 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0619 | Average Loss: 0.4139
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:127 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0462 | Average Loss: 0.4126
# Epoch:127 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.1263 | Average Loss: 0.4112
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:128 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0656 | Average Loss: 0.4099
# Epoch:128 | Iter:   20 | Time: 00:00:20 | Train Loss: 0.0739 | Average Loss: 0.4085
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:129 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.0921 | Average Loss: 0.4073
# Epoch:129 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0816 | Average Loss: 0.4059
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:130 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0838 | Average Loss: 0.4048
# Epoch:130 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0887 | Average Loss: 0.4035
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:131 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0698 | Average Loss: 0.4024
# Epoch:131 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0423 | Average Loss: 0.4011
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:132 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0522 | Average Loss: 0.4000
# Epoch:132 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0534 | Average Loss: 0.3986
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:133 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.1105 | Average Loss: 0.3975
# Epoch:133 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0663 | Average Loss: 0.3961
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:134 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0665 | Average Loss: 0.3950
# Epoch:134 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.0442 | Average Loss: 0.3937
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:135 | Iter:    0 | Time: 00:00:21 | Train Loss: 0.0569 | Average Loss: 0.3926
# Epoch:135 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0374 | Average Loss: 0.3912
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:136 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0399 | Average Loss: 0.3900
# Epoch:136 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0413 | Average Loss: 0.3887
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:137 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.1171 | Average Loss: 0.3876
# Epoch:137 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0630 | Average Loss: 0.3863
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:138 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0519 | Average Loss: 0.3852
# Epoch:138 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0713 | Average Loss: 0.3839
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:139 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0293 | Average Loss: 0.3828
# Epoch:139 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0472 | Average Loss: 0.3816
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:140 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0505 | Average Loss: 0.3805
# Epoch:140 | Iter:   20 | Time: 00:00:22 | Train Loss: 0.0438 | Average Loss: 0.3793
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:141 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.0314 | Average Loss: 0.3782
# Epoch:141 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0822 | Average Loss: 0.3770
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:142 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0928 | Average Loss: 0.3760
# Epoch:142 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0647 | Average Loss: 0.3747
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:143 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0756 | Average Loss: 0.3737
# Epoch:143 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0535 | Average Loss: 0.3725
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:144 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0839 | Average Loss: 0.3714
# Epoch:144 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0848 | Average Loss: 0.3703
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:145 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0544 | Average Loss: 0.3693
# Epoch:145 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0478 | Average Loss: 0.3681
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:146 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0637 | Average Loss: 0.3671
# Epoch:146 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0267 | Average Loss: 0.3659
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:147 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.0488 | Average Loss: 0.3649
# Epoch:147 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.0649 | Average Loss: 0.3638
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:148 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.0482 | Average Loss: 0.3628
# Epoch:148 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.0476 | Average Loss: 0.3617
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:149 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.0421 | Average Loss: 0.3607
# Epoch:149 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.0320 | Average Loss: 0.3596
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:150 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.0593 | Average Loss: 0.3586
# Epoch:150 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.0605 | Average Loss: 0.3575
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:151 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.1027 | Average Loss: 0.3565
# Epoch:151 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.0267 | Average Loss: 0.3555
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:152 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.1078 | Average Loss: 0.3546
# Epoch:152 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.0527 | Average Loss: 0.3535
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:153 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.1408 | Average Loss: 0.3525
# Epoch:153 | Iter:   20 | Time: 00:00:24 | Train Loss: 0.0444 | Average Loss: 0.3515
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:154 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0419 | Average Loss: 0.3505
# Epoch:154 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.0708 | Average Loss: 0.3495
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:155 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0311 | Average Loss: 0.3486
# Epoch:155 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.0362 | Average Loss: 0.3475
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:156 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0491 | Average Loss: 0.3466
# Epoch:156 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.0441 | Average Loss: 0.3456
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:157 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0627 | Average Loss: 0.3447
# Epoch:157 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.1095 | Average Loss: 0.3437
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:158 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0664 | Average Loss: 0.3428
# Epoch:158 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.0753 | Average Loss: 0.3418
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:159 | Iter:    0 | Time: 00:00:25 | Train Loss: 0.0424 | Average Loss: 0.3410
# Epoch:159 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.0567 | Average Loss: 0.3400
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:160 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.0434 | Average Loss: 0.3391
# Epoch:160 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.0528 | Average Loss: 0.3381
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:161 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.0260 | Average Loss: 0.3373
# Epoch:161 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.0618 | Average Loss: 0.3364
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:162 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.0477 | Average Loss: 0.3355
# Epoch:162 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.0499 | Average Loss: 0.3346
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:163 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.0663 | Average Loss: 0.3337
# Epoch:163 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.0851 | Average Loss: 0.3328
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:164 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.0574 | Average Loss: 0.3320
# Epoch:164 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.0237 | Average Loss: 0.3310
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:165 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.0467 | Average Loss: 0.3302
# Epoch:165 | Iter:   20 | Time: 00:00:26 | Train Loss: 0.0351 | Average Loss: 0.3293
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:166 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.0393 | Average Loss: 0.3285
# Epoch:166 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.0851 | Average Loss: 0.3275
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:167 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0232 | Average Loss: 0.3267
# Epoch:167 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.0500 | Average Loss: 0.3258
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:168 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0777 | Average Loss: 0.3250
# Epoch:168 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.0937 | Average Loss: 0.3242
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:169 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0425 | Average Loss: 0.3234
# Epoch:169 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.0463 | Average Loss: 0.3225
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:170 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0665 | Average Loss: 0.3218
# Epoch:170 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.0745 | Average Loss: 0.3209
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:171 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0354 | Average Loss: 0.3201
# Epoch:171 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.1004 | Average Loss: 0.3192
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:172 | Iter:    0 | Time: 00:00:27 | Train Loss: 0.0767 | Average Loss: 0.3185
# Epoch:172 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.0311 | Average Loss: 0.3176
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:173 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0379 | Average Loss: 0.3169
# Epoch:173 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.0829 | Average Loss: 0.3160
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:174 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0333 | Average Loss: 0.3153
# Epoch:174 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.0375 | Average Loss: 0.3144
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:175 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0368 | Average Loss: 0.3137
# Epoch:175 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.0158 | Average Loss: 0.3128
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:176 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0353 | Average Loss: 0.3120
# Epoch:176 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.0516 | Average Loss: 0.3112
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:177 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0237 | Average Loss: 0.3105
# Epoch:177 | Iter:   20 | Time: 00:00:28 | Train Loss: 0.0578 | Average Loss: 0.3097
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:178 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.0594 | Average Loss: 0.3089
# Epoch:178 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.0199 | Average Loss: 0.3081
# Accuracy: 0.583333 | Time: 00:00:00
# Epoch:179 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.0186 | Average Loss: 0.3074
# Epoch:179 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.0585 | Average Loss: 0.3066
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:180 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.0243 | Average Loss: 0.3059
# Epoch:180 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.0240 | Average Loss: 0.3050
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:181 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.0391 | Average Loss: 0.3043
# Epoch:181 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.0290 | Average Loss: 0.3035
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:182 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.0335 | Average Loss: 0.3028
# Epoch:182 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.0233 | Average Loss: 0.3020
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:183 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.0312 | Average Loss: 0.3013
# Epoch:183 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.0206 | Average Loss: 0.3006
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:184 | Iter:    0 | Time: 00:00:29 | Train Loss: 0.0151 | Average Loss: 0.2999
# Epoch:184 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.0218 | Average Loss: 0.2991
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:185 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0526 | Average Loss: 0.2984
# Epoch:185 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.0192 | Average Loss: 0.2977
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:186 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0470 | Average Loss: 0.2970
# Epoch:186 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.0221 | Average Loss: 0.2963
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:187 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.1352 | Average Loss: 0.2957
# Epoch:187 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.0617 | Average Loss: 0.2949
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:188 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0691 | Average Loss: 0.2943
# Epoch:188 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.0191 | Average Loss: 0.2935
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:189 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0268 | Average Loss: 0.2929
# Epoch:189 | Iter:   20 | Time: 00:00:30 | Train Loss: 0.0196 | Average Loss: 0.2922
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:190 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.0212 | Average Loss: 0.2915
# Epoch:190 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.0178 | Average Loss: 0.2908
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:191 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.0408 | Average Loss: 0.2902
# Epoch:191 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.0285 | Average Loss: 0.2895
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:192 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.0293 | Average Loss: 0.2889
# Epoch:192 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.0513 | Average Loss: 0.2882
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:193 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.1161 | Average Loss: 0.2876
# Epoch:193 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.0175 | Average Loss: 0.2869
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:194 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.0430 | Average Loss: 0.2863
# Epoch:194 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.0563 | Average Loss: 0.2856
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:195 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.0389 | Average Loss: 0.2850
# Epoch:195 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.0496 | Average Loss: 0.2843
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:196 | Iter:    0 | Time: 00:00:31 | Train Loss: 0.0283 | Average Loss: 0.2837
# Epoch:196 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0245 | Average Loss: 0.2830
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:197 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0563 | Average Loss: 0.2824
# Epoch:197 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0356 | Average Loss: 0.2817
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:198 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0288 | Average Loss: 0.2812
# Epoch:198 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0381 | Average Loss: 0.2805
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:199 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0187 | Average Loss: 0.2799
# Epoch:199 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0201 | Average Loss: 0.2792
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:200 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0236 | Average Loss: 0.2786
# Epoch:200 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0130 | Average Loss: 0.2779
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:201 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0292 | Average Loss: 0.2774
# Epoch:201 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0238 | Average Loss: 0.2767
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:202 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.0687 | Average Loss: 0.2762
# Epoch:202 | Iter:   20 | Time: 00:00:32 | Train Loss: 0.0190 | Average Loss: 0.2755
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:203 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.0205 | Average Loss: 0.2749
# Epoch:203 | Iter:   20 | Time: 00:00:33 | Train Loss: 0.0227 | Average Loss: 0.2743
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:204 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.0253 | Average Loss: 0.2738
# Epoch:204 | Iter:   20 | Time: 00:00:33 | Train Loss: 0.0298 | Average Loss: 0.2731
# Accuracy: 0.588542 | Time: 00:00:00
# Epoch:205 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.0212 | Average Loss: 0.2726
# Epoch:205 | Iter:   20 | Time: 00:00:33 | Train Loss: 0.0135 | Average Loss: 0.2719
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:206 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.0233 | Average Loss: 0.2714
# Epoch:206 | Iter:   20 | Time: 00:00:33 | Train Loss: 0.0251 | Average Loss: 0.2708
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:207 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.0498 | Average Loss: 0.2702
# Epoch:207 | Iter:   20 | Time: 00:00:33 | Train Loss: 0.0384 | Average Loss: 0.2696
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:208 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.0897 | Average Loss: 0.2690
# Epoch:208 | Iter:   20 | Time: 00:00:33 | Train Loss: 0.0374 | Average Loss: 0.2684
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:209 | Iter:    0 | Time: 00:00:34 | Train Loss: 0.0166 | Average Loss: 0.2679
# Epoch:209 | Iter:   20 | Time: 00:00:34 | Train Loss: 0.0268 | Average Loss: 0.2673
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:210 | Iter:    0 | Time: 00:00:34 | Train Loss: 0.0394 | Average Loss: 0.2667
# Epoch:210 | Iter:   20 | Time: 00:00:34 | Train Loss: 0.0219 | Average Loss: 0.2661
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:211 | Iter:    0 | Time: 00:00:34 | Train Loss: 0.0184 | Average Loss: 0.2656
# Epoch:211 | Iter:   20 | Time: 00:00:34 | Train Loss: 0.0571 | Average Loss: 0.2650
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:212 | Iter:    0 | Time: 00:00:34 | Train Loss: 0.0324 | Average Loss: 0.2645
# Epoch:212 | Iter:   20 | Time: 00:00:34 | Train Loss: 0.0482 | Average Loss: 0.2639
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:213 | Iter:    0 | Time: 00:00:34 | Train Loss: 0.1156 | Average Loss: 0.2634
# Epoch:213 | Iter:   20 | Time: 00:00:34 | Train Loss: 0.0270 | Average Loss: 0.2628
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:214 | Iter:    0 | Time: 00:00:34 | Train Loss: 0.0186 | Average Loss: 0.2623
# Epoch:214 | Iter:   20 | Time: 00:00:34 | Train Loss: 0.0102 | Average Loss: 0.2618
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:215 | Iter:    0 | Time: 00:00:35 | Train Loss: 0.0751 | Average Loss: 0.2613
# Epoch:215 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.0227 | Average Loss: 0.2607
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:216 | Iter:    0 | Time: 00:00:35 | Train Loss: 0.0143 | Average Loss: 0.2602
# Epoch:216 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.0326 | Average Loss: 0.2596
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:217 | Iter:    0 | Time: 00:00:35 | Train Loss: 0.0180 | Average Loss: 0.2591
# Epoch:217 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.0283 | Average Loss: 0.2586
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:218 | Iter:    0 | Time: 00:00:35 | Train Loss: 0.0386 | Average Loss: 0.2581
# Epoch:218 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.0110 | Average Loss: 0.2575
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:219 | Iter:    0 | Time: 00:00:35 | Train Loss: 0.0128 | Average Loss: 0.2570
# Epoch:219 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.0284 | Average Loss: 0.2565
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:220 | Iter:    0 | Time: 00:00:35 | Train Loss: 0.0091 | Average Loss: 0.2560
# Epoch:220 | Iter:   20 | Time: 00:00:35 | Train Loss: 0.0231 | Average Loss: 0.2554
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:221 | Iter:    0 | Time: 00:00:36 | Train Loss: 0.0420 | Average Loss: 0.2550
# Epoch:221 | Iter:   20 | Time: 00:00:36 | Train Loss: 0.0288 | Average Loss: 0.2545
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:222 | Iter:    0 | Time: 00:00:36 | Train Loss: 0.0308 | Average Loss: 0.2540
# Epoch:222 | Iter:   20 | Time: 00:00:36 | Train Loss: 0.0260 | Average Loss: 0.2535
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:223 | Iter:    0 | Time: 00:00:36 | Train Loss: 0.0566 | Average Loss: 0.2530
# Epoch:223 | Iter:   20 | Time: 00:00:36 | Train Loss: 0.0342 | Average Loss: 0.2525
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:224 | Iter:    0 | Time: 00:00:36 | Train Loss: 0.0398 | Average Loss: 0.2521
# Epoch:224 | Iter:   20 | Time: 00:00:36 | Train Loss: 0.0512 | Average Loss: 0.2515
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:225 | Iter:    0 | Time: 00:00:36 | Train Loss: 0.0225 | Average Loss: 0.2511
# Epoch:225 | Iter:   20 | Time: 00:00:36 | Train Loss: 0.0284 | Average Loss: 0.2505
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:226 | Iter:    0 | Time: 00:00:36 | Train Loss: 0.0810 | Average Loss: 0.2501
# Epoch:226 | Iter:   20 | Time: 00:00:36 | Train Loss: 0.0164 | Average Loss: 0.2497
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:227 | Iter:    0 | Time: 00:00:37 | Train Loss: 0.0811 | Average Loss: 0.2492
# Epoch:227 | Iter:   20 | Time: 00:00:37 | Train Loss: 0.0426 | Average Loss: 0.2487
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:228 | Iter:    0 | Time: 00:00:37 | Train Loss: 0.0166 | Average Loss: 0.2483
# Epoch:228 | Iter:   20 | Time: 00:00:37 | Train Loss: 0.0300 | Average Loss: 0.2478
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:229 | Iter:    0 | Time: 00:00:37 | Train Loss: 0.0259 | Average Loss: 0.2474
# Epoch:229 | Iter:   20 | Time: 00:00:37 | Train Loss: 0.0385 | Average Loss: 0.2469
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:230 | Iter:    0 | Time: 00:00:37 | Train Loss: 0.0149 | Average Loss: 0.2465
# Epoch:230 | Iter:   20 | Time: 00:00:37 | Train Loss: 0.0166 | Average Loss: 0.2459
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:231 | Iter:    0 | Time: 00:00:37 | Train Loss: 0.0415 | Average Loss: 0.2455
# Epoch:231 | Iter:   20 | Time: 00:00:37 | Train Loss: 0.0250 | Average Loss: 0.2450
# Accuracy: 0.604167 | Time: 00:00:00
# Epoch:232 | Iter:    0 | Time: 00:00:37 | Train Loss: 0.0566 | Average Loss: 0.2447
# Epoch:232 | Iter:   20 | Time: 00:00:37 | Train Loss: 0.0255 | Average Loss: 0.2442
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:233 | Iter:    0 | Time: 00:00:37 | Train Loss: 0.0646 | Average Loss: 0.2438
# Epoch:233 | Iter:   20 | Time: 00:00:38 | Train Loss: 0.0333 | Average Loss: 0.2433
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:234 | Iter:    0 | Time: 00:00:38 | Train Loss: 0.0429 | Average Loss: 0.2429
# Epoch:234 | Iter:   20 | Time: 00:00:38 | Train Loss: 0.0456 | Average Loss: 0.2424
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:235 | Iter:    0 | Time: 00:00:38 | Train Loss: 0.0214 | Average Loss: 0.2420
# Epoch:235 | Iter:   20 | Time: 00:00:38 | Train Loss: 0.0563 | Average Loss: 0.2415
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:236 | Iter:    0 | Time: 00:00:38 | Train Loss: 0.0170 | Average Loss: 0.2411
# Epoch:236 | Iter:   20 | Time: 00:00:38 | Train Loss: 0.0333 | Average Loss: 0.2406
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:237 | Iter:    0 | Time: 00:00:38 | Train Loss: 0.0569 | Average Loss: 0.2402
# Epoch:237 | Iter:   20 | Time: 00:00:38 | Train Loss: 0.0274 | Average Loss: 0.2398
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:238 | Iter:    0 | Time: 00:00:38 | Train Loss: 0.0219 | Average Loss: 0.2393
# Epoch:238 | Iter:   20 | Time: 00:00:38 | Train Loss: 0.0326 | Average Loss: 0.2389
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:239 | Iter:    0 | Time: 00:00:38 | Train Loss: 0.0796 | Average Loss: 0.2385
# Epoch:239 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.0250 | Average Loss: 0.2380
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:240 | Iter:    0 | Time: 00:00:39 | Train Loss: 0.0248 | Average Loss: 0.2376
# Epoch:240 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.0466 | Average Loss: 0.2372
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:241 | Iter:    0 | Time: 00:00:39 | Train Loss: 0.0318 | Average Loss: 0.2368
# Epoch:241 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.0216 | Average Loss: 0.2364
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:242 | Iter:    0 | Time: 00:00:39 | Train Loss: 0.0402 | Average Loss: 0.2360
# Epoch:242 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.0760 | Average Loss: 0.2355
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:243 | Iter:    0 | Time: 00:00:39 | Train Loss: 0.0380 | Average Loss: 0.2351
# Epoch:243 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.0639 | Average Loss: 0.2347
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:244 | Iter:    0 | Time: 00:00:39 | Train Loss: 0.0485 | Average Loss: 0.2343
# Epoch:244 | Iter:   20 | Time: 00:00:39 | Train Loss: 0.0356 | Average Loss: 0.2339
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:245 | Iter:    0 | Time: 00:00:39 | Train Loss: 0.0163 | Average Loss: 0.2335
# Epoch:245 | Iter:   20 | Time: 00:00:40 | Train Loss: 0.0176 | Average Loss: 0.2330
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:246 | Iter:    0 | Time: 00:00:40 | Train Loss: 0.0211 | Average Loss: 0.2327
# Epoch:246 | Iter:   20 | Time: 00:00:40 | Train Loss: 0.0226 | Average Loss: 0.2322
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:247 | Iter:    0 | Time: 00:00:40 | Train Loss: 0.0164 | Average Loss: 0.2319
# Epoch:247 | Iter:   20 | Time: 00:00:40 | Train Loss: 0.0278 | Average Loss: 0.2314
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:248 | Iter:    0 | Time: 00:00:40 | Train Loss: 0.0484 | Average Loss: 0.2311
# Epoch:248 | Iter:   20 | Time: 00:00:40 | Train Loss: 0.0268 | Average Loss: 0.2306
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:249 | Iter:    0 | Time: 00:00:40 | Train Loss: 0.0763 | Average Loss: 0.2303
# Epoch:249 | Iter:   20 | Time: 00:00:40 | Train Loss: 0.0196 | Average Loss: 0.2298
# Accuracy: 0.596354 | Time: 00:00:00
# Epoch:250 | Iter:    0 | Time: 00:00:40 | Train Loss: 0.0187 | Average Loss: 0.2294
# Epoch:250 | Iter:   20 | Time: 00:00:40 | Train Loss: 0.0185 | Average Loss: 0.2290
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:251 | Iter:    0 | Time: 00:00:40 | Train Loss: 0.0236 | Average Loss: 0.2286
# Epoch:251 | Iter:   20 | Time: 00:00:41 | Train Loss: 0.0576 | Average Loss: 0.2282
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:252 | Iter:    0 | Time: 00:00:41 | Train Loss: 0.0508 | Average Loss: 0.2279
# Epoch:252 | Iter:   20 | Time: 00:00:41 | Train Loss: 0.0284 | Average Loss: 0.2274
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:253 | Iter:    0 | Time: 00:00:41 | Train Loss: 0.0304 | Average Loss: 0.2271
# Epoch:253 | Iter:   20 | Time: 00:00:41 | Train Loss: 0.0282 | Average Loss: 0.2266
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:254 | Iter:    0 | Time: 00:00:41 | Train Loss: 0.0061 | Average Loss: 0.2263
# Epoch:254 | Iter:   20 | Time: 00:00:41 | Train Loss: 0.0145 | Average Loss: 0.2258
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:255 | Iter:    0 | Time: 00:00:41 | Train Loss: 0.0178 | Average Loss: 0.2255
# Epoch:255 | Iter:   20 | Time: 00:00:41 | Train Loss: 0.0125 | Average Loss: 0.2251
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:256 | Iter:    0 | Time: 00:00:41 | Train Loss: 0.0235 | Average Loss: 0.2247
# Epoch:256 | Iter:   20 | Time: 00:00:41 | Train Loss: 0.0724 | Average Loss: 0.2243
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:257 | Iter:    0 | Time: 00:00:41 | Train Loss: 0.0266 | Average Loss: 0.2239
# Epoch:257 | Iter:   20 | Time: 00:00:42 | Train Loss: 0.0514 | Average Loss: 0.2235
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:258 | Iter:    0 | Time: 00:00:42 | Train Loss: 0.0283 | Average Loss: 0.2231
# Epoch:258 | Iter:   20 | Time: 00:00:42 | Train Loss: 0.0121 | Average Loss: 0.2227
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:259 | Iter:    0 | Time: 00:00:42 | Train Loss: 0.0386 | Average Loss: 0.2224
# Epoch:259 | Iter:   20 | Time: 00:00:42 | Train Loss: 0.0341 | Average Loss: 0.2220
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:260 | Iter:    0 | Time: 00:00:42 | Train Loss: 0.0546 | Average Loss: 0.2217
# Epoch:260 | Iter:   20 | Time: 00:00:42 | Train Loss: 0.0621 | Average Loss: 0.2213
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:261 | Iter:    0 | Time: 00:00:42 | Train Loss: 0.0186 | Average Loss: 0.2209
# Epoch:261 | Iter:   20 | Time: 00:00:42 | Train Loss: 0.0309 | Average Loss: 0.2205
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:262 | Iter:    0 | Time: 00:00:42 | Train Loss: 0.0147 | Average Loss: 0.2202
# Epoch:262 | Iter:   20 | Time: 00:00:42 | Train Loss: 0.0652 | Average Loss: 0.2198
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:263 | Iter:    0 | Time: 00:00:42 | Train Loss: 0.0355 | Average Loss: 0.2195
# Epoch:263 | Iter:   20 | Time: 00:00:43 | Train Loss: 0.0368 | Average Loss: 0.2191
# Accuracy: 0.591146 | Time: 00:00:00
# Epoch:264 | Iter:    0 | Time: 00:00:43 | Train Loss: 0.0394 | Average Loss: 0.2188
# Epoch:264 | Iter:   20 | Time: 00:00:43 | Train Loss: 0.0253 | Average Loss: 0.2184
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:265 | Iter:    0 | Time: 00:00:43 | Train Loss: 0.0364 | Average Loss: 0.2180
# Epoch:265 | Iter:   20 | Time: 00:00:43 | Train Loss: 0.0237 | Average Loss: 0.2177
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:266 | Iter:    0 | Time: 00:00:43 | Train Loss: 0.0558 | Average Loss: 0.2173
# Epoch:266 | Iter:   20 | Time: 00:00:43 | Train Loss: 0.0300 | Average Loss: 0.2170
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:267 | Iter:    0 | Time: 00:00:43 | Train Loss: 0.0108 | Average Loss: 0.2167
# Epoch:267 | Iter:   20 | Time: 00:00:43 | Train Loss: 0.0461 | Average Loss: 0.2163
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:268 | Iter:    0 | Time: 00:00:43 | Train Loss: 0.0136 | Average Loss: 0.2160
# Epoch:268 | Iter:   20 | Time: 00:00:43 | Train Loss: 0.0181 | Average Loss: 0.2156
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:269 | Iter:    0 | Time: 00:00:43 | Train Loss: 0.0418 | Average Loss: 0.2153
# Epoch:269 | Iter:   20 | Time: 00:00:44 | Train Loss: 0.0328 | Average Loss: 0.2149
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:270 | Iter:    0 | Time: 00:00:44 | Train Loss: 0.0117 | Average Loss: 0.2146
# Epoch:270 | Iter:   20 | Time: 00:00:44 | Train Loss: 0.0167 | Average Loss: 0.2142
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:271 | Iter:    0 | Time: 00:00:44 | Train Loss: 0.0279 | Average Loss: 0.2138
# Epoch:271 | Iter:   20 | Time: 00:00:44 | Train Loss: 0.0623 | Average Loss: 0.2135
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:272 | Iter:    0 | Time: 00:00:44 | Train Loss: 0.0300 | Average Loss: 0.2132
# Epoch:272 | Iter:   20 | Time: 00:00:44 | Train Loss: 0.0193 | Average Loss: 0.2128
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:273 | Iter:    0 | Time: 00:00:44 | Train Loss: 0.0316 | Average Loss: 0.2125
# Epoch:273 | Iter:   20 | Time: 00:00:44 | Train Loss: 0.0187 | Average Loss: 0.2121
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:274 | Iter:    0 | Time: 00:00:44 | Train Loss: 0.0333 | Average Loss: 0.2118
# Epoch:274 | Iter:   20 | Time: 00:00:44 | Train Loss: 0.0533 | Average Loss: 0.2114
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:275 | Iter:    0 | Time: 00:00:44 | Train Loss: 0.0324 | Average Loss: 0.2111
# Epoch:275 | Iter:   20 | Time: 00:00:44 | Train Loss: 0.0130 | Average Loss: 0.2107
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:276 | Iter:    0 | Time: 00:00:45 | Train Loss: 0.0160 | Average Loss: 0.2104
# Epoch:276 | Iter:   20 | Time: 00:00:45 | Train Loss: 0.0605 | Average Loss: 0.2100
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch:277 | Iter:    0 | Time: 00:00:45 | Train Loss: 0.0579 | Average Loss: 0.2097
# Epoch:277 | Iter:   20 | Time: 00:00:45 | Train Loss: 0.0187 | Average Loss: 0.2094
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:278 | Iter:    0 | Time: 00:00:45 | Train Loss: 0.0273 | Average Loss: 0.2091
# Epoch:278 | Iter:   20 | Time: 00:00:45 | Train Loss: 0.0208 | Average Loss: 0.2087
# Accuracy: 0.570312 | Time: 00:00:00
# Epoch:279 | Iter:    0 | Time: 00:00:45 | Train Loss: 0.0605 | Average Loss: 0.2085
# Epoch:279 | Iter:   20 | Time: 00:00:45 | Train Loss: 0.0321 | Average Loss: 0.2081
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:280 | Iter:    0 | Time: 00:00:45 | Train Loss: 0.0121 | Average Loss: 0.2078
# Epoch:280 | Iter:   20 | Time: 00:00:45 | Train Loss: 0.0107 | Average Loss: 0.2075
# Accuracy: 0.544271 | Time: 00:00:00
# Epoch:281 | Iter:    0 | Time: 00:00:45 | Train Loss: 0.0662 | Average Loss: 0.2072
# Epoch:281 | Iter:   20 | Time: 00:00:45 | Train Loss: 0.0413 | Average Loss: 0.2068
# Accuracy: 0.546875 | Time: 00:00:00
# Epoch:282 | Iter:    0 | Time: 00:00:46 | Train Loss: 0.0369 | Average Loss: 0.2065
# Epoch:282 | Iter:   20 | Time: 00:00:46 | Train Loss: 0.0116 | Average Loss: 0.2062
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:283 | Iter:    0 | Time: 00:00:46 | Train Loss: 0.0598 | Average Loss: 0.2059
# Epoch:283 | Iter:   20 | Time: 00:00:46 | Train Loss: 0.0187 | Average Loss: 0.2056
# Accuracy: 0.565104 | Time: 00:00:00
# Epoch:284 | Iter:    0 | Time: 00:00:46 | Train Loss: 0.0682 | Average Loss: 0.2053
# Epoch:284 | Iter:   20 | Time: 00:00:46 | Train Loss: 0.0184 | Average Loss: 0.2049
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:285 | Iter:    0 | Time: 00:00:46 | Train Loss: 0.0483 | Average Loss: 0.2047
# Epoch:285 | Iter:   20 | Time: 00:00:46 | Train Loss: 0.0338 | Average Loss: 0.2043
# Accuracy: 0.536458 | Time: 00:00:00
# Epoch:286 | Iter:    0 | Time: 00:00:46 | Train Loss: 0.0291 | Average Loss: 0.2041
# Epoch:286 | Iter:   20 | Time: 00:00:46 | Train Loss: 0.0083 | Average Loss: 0.2037
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:287 | Iter:    0 | Time: 00:00:46 | Train Loss: 0.0202 | Average Loss: 0.2034
# Epoch:287 | Iter:   20 | Time: 00:00:46 | Train Loss: 0.0157 | Average Loss: 0.2031
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:288 | Iter:    0 | Time: 00:00:47 | Train Loss: 0.0222 | Average Loss: 0.2028
# Epoch:288 | Iter:   20 | Time: 00:00:47 | Train Loss: 0.0417 | Average Loss: 0.2025
# Accuracy: 0.578125 | Time: 00:00:00
# Epoch:289 | Iter:    0 | Time: 00:00:47 | Train Loss: 0.0111 | Average Loss: 0.2022
# Epoch:289 | Iter:   20 | Time: 00:00:47 | Train Loss: 0.0573 | Average Loss: 0.2019
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:290 | Iter:    0 | Time: 00:00:47 | Train Loss: 0.0112 | Average Loss: 0.2016
# Epoch:290 | Iter:   20 | Time: 00:00:47 | Train Loss: 0.0471 | Average Loss: 0.2013
# Accuracy: 0.580729 | Time: 00:00:00
# Epoch:291 | Iter:    0 | Time: 00:00:47 | Train Loss: 0.0357 | Average Loss: 0.2010
# Epoch:291 | Iter:   20 | Time: 00:00:47 | Train Loss: 0.0410 | Average Loss: 0.2007
# Accuracy: 0.554688 | Time: 00:00:00
# Epoch:292 | Iter:    0 | Time: 00:00:47 | Train Loss: 0.0409 | Average Loss: 0.2004
# Epoch:292 | Iter:   20 | Time: 00:00:47 | Train Loss: 0.0050 | Average Loss: 0.2001
# Accuracy: 0.557292 | Time: 00:00:00
# Epoch:293 | Iter:    0 | Time: 00:00:47 | Train Loss: 0.0273 | Average Loss: 0.1998
# Epoch:293 | Iter:   20 | Time: 00:00:47 | Train Loss: 0.0145 | Average Loss: 0.1995
# Accuracy: 0.567708 | Time: 00:00:00
# Epoch:294 | Iter:    0 | Time: 00:00:48 | Train Loss: 0.0724 | Average Loss: 0.1993
# Epoch:294 | Iter:   20 | Time: 00:00:48 | Train Loss: 0.0350 | Average Loss: 0.1990
# Accuracy: 0.541667 | Time: 00:00:00
# Epoch:295 | Iter:    0 | Time: 00:00:48 | Train Loss: 0.0170 | Average Loss: 0.1987
# Epoch:295 | Iter:   20 | Time: 00:00:48 | Train Loss: 0.0098 | Average Loss: 0.1984
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch:296 | Iter:    0 | Time: 00:00:48 | Train Loss: 0.0500 | Average Loss: 0.1981
# Epoch:296 | Iter:   20 | Time: 00:00:48 | Train Loss: 0.0090 | Average Loss: 0.1978
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:297 | Iter:    0 | Time: 00:00:48 | Train Loss: 0.0256 | Average Loss: 0.1975
# Epoch:297 | Iter:   20 | Time: 00:00:48 | Train Loss: 0.0216 | Average Loss: 0.1972
# Accuracy: 0.572917 | Time: 00:00:00
# Epoch:298 | Iter:    0 | Time: 00:00:48 | Train Loss: 0.0092 | Average Loss: 0.1969
# Epoch:298 | Iter:   20 | Time: 00:00:48 | Train Loss: 0.0078 | Average Loss: 0.1966
# Accuracy: 0.552083 | Time: 00:00:00
# Epoch:299 | Iter:    0 | Time: 00:00:48 | Train Loss: 0.0422 | Average Loss: 0.1964
# Epoch:299 | Iter:   20 | Time: 00:00:48 | Train Loss: 0.0185 | Average Loss: 0.1960
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:300 | Iter:    0 | Time: 00:00:48 | Train Loss: 0.0457 | Average Loss: 0.1958
# Epoch:300 | Iter:   20 | Time: 00:00:49 | Train Loss: 0.0096 | Average Loss: 0.1955
# Accuracy: 0.544271 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# Technique 3: Adding Hyperbolic Tangent Step Function
#
# Accuracy on test set: .604167
#
# Accuracy increases/decreases: .018229

# %% [markdown]
# ## Problem 2: Fine Tuning a Pre-Trained Deep Network
# Our convolutional network to this point isn't "deep". Fortunately, the representations learned by deep convolutional networks is that they generalize surprisingly well to other recognition tasks.
#
# But how do we use an existing deep network for a new recognition task? Take for instance,  [AlexNet](http://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks) network has 1000 units in the final layer corresponding to 1000 ImageNet categories.
#
#
# **Hints**:
# - Many pre-trained models are available in PyTorch at [here](http://pytorch.org/docs/master/torchvision/models.html).
# - For fine-tuning pretrained network using PyTorch, please read this [tutorial](http://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html).

# %% [markdown]
# ### Problem 2.1
#
# **Strategy A**: *Fine-tune* an existing network. In this scenario you take an existing network, replace the final layer (or more) with random weights, and train the entire network again with images and ground truth labels for your recognition task. You are effectively treating the pre-trained deep network as a better initialization than the random weights used when training from scratch. When you don't have enough training data to train a complex network from scratch (e.g. with the 16 classes) this is an attractive option. Fine-tuning can work far better than Strategy B of taking the activations directly from an pre-trained CNN. For example, in [this paper](http://www.cc.gatech.edu/~hays/papers/deep_geo.pdf) from CVPR 2015, there wasn't enough data to train a deep network from scratch, but fine tuning led to 4 times higher accuracy than using off-the-shelf networks directly.
#
# (25 points) You are required to implement Strategy A to fine-tune a pre-trained **AlexNet** for this scene classification task. You should be able to achieve accuracy of **0.85** approximately. The minimum accuracy required for this section is **0.75**.
#
# Please provide detailed descriptions of:<br>
# (1) which layers of AlexNet have been replaced<br>
# (2) the architecture of the new layers added including activation methods (same as problem 1)<br>
# (3) the final accuracy on test set <br>

# %%
# reload data with a larger size
img_size = (224, 224)
batch_size = 64 # training sample number per batch 

# load training dataset
trainloader_large = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, 
                                      augment=True, is_color=True, zero_centered=True))
train_num = len(trainloader_large)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_large = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, is_color=True, zero_centered=True))
test_num = len(testloader_large)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 37 minibatches (batch_size=64) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Finish loading 6 minibatches (batch_size=64) of testing samples.

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
import torch

model = torch.hub.load('pytorch/vision:v0.9.0', 'alexnet', pretrained=True)
#change classifier
model.classifier[3] = nn.Sigmoid()
model.classifier[4]= nn.Linear(in_features=4096,out_features=1000,bias=True)
model.classifier[6]= nn.Linear(in_features=1000,out_features=16,bias=True)

train_option = {}
train_option['lr'] = 0.001
train_option['epoch'] = 120
train_option['device'] = 'gpu'
trainModel(model, trainloader_large, train_option, testloader_large)
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.9.0
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#   (1): ReLU(inplace=True)
#   (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (4): ReLU(inplace=True)
#   (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU(inplace=True)
#   (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU(inplace=True)
#   (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): ReLU(inplace=True)
#   (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
# )
# Sequential(
#   (0): Dropout(p=0.5, inplace=False)
#   (1): Linear(in_features=9216, out_features=4096, bias=True)
#   (2): ReLU(inplace=True)
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=4096, out_features=4096, bias=True)
#   (5): ReLU(inplace=True)
#   (6): Linear(in_features=4096, out_features=1000, bias=True)
# )
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7682 | Average Loss: 2.7682
# Epoch: 1 | Iter:   20 | Time: 00:00:01 | Train Loss: 2.7443 | Average Loss: 3.3633
# Accuracy: 0.190104 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.4254 | Average Loss: 3.0141
# Epoch: 2 | Iter:   20 | Time: 00:00:02 | Train Loss: 2.1041 | Average Loss: 2.7660
# Accuracy: 0.346354 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.9402 | Average Loss: 2.5710
# Epoch: 3 | Iter:   20 | Time: 00:00:04 | Train Loss: 1.7834 | Average Loss: 2.4135
# Accuracy: 0.380208 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.6735 | Average Loss: 2.2914
# Epoch: 4 | Iter:   20 | Time: 00:00:06 | Train Loss: 1.4393 | Average Loss: 2.1743
# Accuracy: 0.455729 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.4035 | Average Loss: 2.0792
# Epoch: 5 | Iter:   20 | Time: 00:00:08 | Train Loss: 1.2793 | Average Loss: 1.9867
# Accuracy: 0.515625 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:09 | Train Loss: 1.4919 | Average Loss: 1.9168
# Epoch: 6 | Iter:   20 | Time: 00:00:10 | Train Loss: 1.2066 | Average Loss: 1.8407
# Accuracy: 0.539062 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:11 | Train Loss: 1.1032 | Average Loss: 1.7824
# Epoch: 7 | Iter:   20 | Time: 00:00:12 | Train Loss: 0.9378 | Average Loss: 1.7150
# Accuracy: 0.549479 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:13 | Train Loss: 1.0342 | Average Loss: 1.6751
# Epoch: 8 | Iter:   20 | Time: 00:00:14 | Train Loss: 0.9521 | Average Loss: 1.6218
# Accuracy: 0.559896 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:15 | Train Loss: 1.1289 | Average Loss: 1.5825
# Epoch: 9 | Iter:   20 | Time: 00:00:16 | Train Loss: 1.0307 | Average Loss: 1.5369
# Accuracy: 0.585938 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:17 | Train Loss: 1.0825 | Average Loss: 1.5031
# Epoch:10 | Iter:   20 | Time: 00:00:17 | Train Loss: 0.7849 | Average Loss: 1.4562
# Accuracy: 0.614583 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.6677 | Average Loss: 1.4202
# Epoch:11 | Iter:   20 | Time: 00:00:19 | Train Loss: 0.7192 | Average Loss: 1.3758
# Accuracy: 0.622396 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.6423 | Average Loss: 1.3421
# Epoch:12 | Iter:   20 | Time: 00:00:21 | Train Loss: 0.5871 | Average Loss: 1.3052
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:22 | Train Loss: 0.4816 | Average Loss: 1.2737
# Epoch:13 | Iter:   20 | Time: 00:00:23 | Train Loss: 0.4131 | Average Loss: 1.2391
# Accuracy: 0.638021 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:24 | Train Loss: 0.5831 | Average Loss: 1.2130
# Epoch:14 | Iter:   20 | Time: 00:00:25 | Train Loss: 0.7101 | Average Loss: 1.1850
# Accuracy: 0.671875 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:26 | Train Loss: 0.7043 | Average Loss: 1.1619
# Epoch:15 | Iter:   20 | Time: 00:00:27 | Train Loss: 0.5569 | Average Loss: 1.1348
# Accuracy: 0.601562 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:28 | Train Loss: 0.7336 | Average Loss: 1.1131
# Epoch:16 | Iter:   20 | Time: 00:00:29 | Train Loss: 0.3679 | Average Loss: 1.0894
# Accuracy: 0.575521 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:30 | Train Loss: 0.5524 | Average Loss: 1.0697
# Epoch:17 | Iter:   20 | Time: 00:00:31 | Train Loss: 0.3174 | Average Loss: 1.0454
# Accuracy: 0.716146 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:32 | Train Loss: 0.2140 | Average Loss: 1.0251
# Epoch:18 | Iter:   20 | Time: 00:00:33 | Train Loss: 0.3467 | Average Loss: 1.0012
# Accuracy: 0.705729 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:33 | Train Loss: 0.2517 | Average Loss: 0.9812
# Epoch:19 | Iter:   20 | Time: 00:00:34 | Train Loss: 0.1878 | Average Loss: 0.9578
# Accuracy: 0.716146 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:35 | Train Loss: 0.2359 | Average Loss: 0.9388
# Epoch:20 | Iter:   20 | Time: 00:00:36 | Train Loss: 0.2556 | Average Loss: 0.9168
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:37 | Train Loss: 0.1600 | Average Loss: 0.8987
# Epoch:21 | Iter:   20 | Time: 00:00:38 | Train Loss: 0.1319 | Average Loss: 0.8782
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:39 | Train Loss: 0.1226 | Average Loss: 0.8614
# Epoch:22 | Iter:   20 | Time: 00:00:40 | Train Loss: 0.0573 | Average Loss: 0.8421
# Accuracy: 0.716146 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:41 | Train Loss: 0.1034 | Average Loss: 0.8267
# Epoch:23 | Iter:   20 | Time: 00:00:42 | Train Loss: 0.1423 | Average Loss: 0.8101
# Accuracy: 0.669271 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:43 | Train Loss: 0.2074 | Average Loss: 0.7963
# Epoch:24 | Iter:   20 | Time: 00:00:44 | Train Loss: 0.0491 | Average Loss: 0.7805
# Accuracy: 0.684896 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:45 | Train Loss: 0.1043 | Average Loss: 0.7671
# Epoch:25 | Iter:   20 | Time: 00:00:46 | Train Loss: 0.1087 | Average Loss: 0.7529
# Accuracy: 0.723958 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:47 | Train Loss: 0.0225 | Average Loss: 0.7408
# Epoch:26 | Iter:   20 | Time: 00:00:48 | Train Loss: 0.0430 | Average Loss: 0.7268
# Accuracy: 0.653646 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:49 | Train Loss: 0.1477 | Average Loss: 0.7154
# Epoch:27 | Iter:   20 | Time: 00:00:50 | Train Loss: 0.1430 | Average Loss: 0.7031
# Accuracy: 0.690104 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:50 | Train Loss: 0.1556 | Average Loss: 0.6929
# Epoch:28 | Iter:   20 | Time: 00:00:51 | Train Loss: 0.0243 | Average Loss: 0.6806
# Accuracy: 0.703125 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:52 | Train Loss: 0.0845 | Average Loss: 0.6703
# Epoch:29 | Iter:   20 | Time: 00:00:53 | Train Loss: 0.0146 | Average Loss: 0.6583
# Accuracy: 0.744792 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:54 | Train Loss: 0.0347 | Average Loss: 0.6484
# Epoch:30 | Iter:   20 | Time: 00:00:55 | Train Loss: 0.0541 | Average Loss: 0.6371
# Accuracy: 0.731771 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:56 | Train Loss: 0.1420 | Average Loss: 0.6280
# Epoch:31 | Iter:   20 | Time: 00:00:57 | Train Loss: 0.0772 | Average Loss: 0.6176
# Accuracy: 0.690104 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:58 | Train Loss: 0.0905 | Average Loss: 0.6091
# Epoch:32 | Iter:   20 | Time: 00:00:59 | Train Loss: 0.0625 | Average Loss: 0.5993
# Accuracy: 0.713542 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:01:00 | Train Loss: 0.0243 | Average Loss: 0.5911
# Epoch:33 | Iter:   20 | Time: 00:01:01 | Train Loss: 0.0193 | Average Loss: 0.5821
# Accuracy: 0.736979 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:01:02 | Train Loss: 0.0569 | Average Loss: 0.5748
# Epoch:34 | Iter:   20 | Time: 00:01:03 | Train Loss: 0.0118 | Average Loss: 0.5666
# Accuracy: 0.684896 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:01:04 | Train Loss: 0.0298 | Average Loss: 0.5602
# Epoch:35 | Iter:   20 | Time: 00:01:05 | Train Loss: 0.0433 | Average Loss: 0.5526
# Accuracy: 0.700521 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:01:06 | Train Loss: 0.0872 | Average Loss: 0.5459
# Epoch:36 | Iter:   20 | Time: 00:01:06 | Train Loss: 0.0537 | Average Loss: 0.5383
# Accuracy: 0.671875 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:01:07 | Train Loss: 0.0778 | Average Loss: 0.5324
# Epoch:37 | Iter:   20 | Time: 00:01:08 | Train Loss: 0.1309 | Average Loss: 0.5256
# Accuracy: 0.661458 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:01:09 | Train Loss: 0.1213 | Average Loss: 0.5203
# Epoch:38 | Iter:   20 | Time: 00:01:10 | Train Loss: 0.0282 | Average Loss: 0.5148
# Accuracy: 0.632812 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:01:11 | Train Loss: 0.0669 | Average Loss: 0.5098
# Epoch:39 | Iter:   20 | Time: 00:01:12 | Train Loss: 0.0396 | Average Loss: 0.5035
# Accuracy: 0.710938 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:01:13 | Train Loss: 0.0432 | Average Loss: 0.4980
# Epoch:40 | Iter:   20 | Time: 00:01:14 | Train Loss: 0.0894 | Average Loss: 0.4920
# Accuracy: 0.739583 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:01:15 | Train Loss: 0.0320 | Average Loss: 0.4874
# Epoch:41 | Iter:   20 | Time: 00:01:16 | Train Loss: 0.1167 | Average Loss: 0.4813
# Accuracy: 0.705729 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:01:17 | Train Loss: 0.2566 | Average Loss: 0.4770
# Epoch:42 | Iter:   20 | Time: 00:01:18 | Train Loss: 0.0456 | Average Loss: 0.4715
# Accuracy: 0.713542 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:01:19 | Train Loss: 0.0250 | Average Loss: 0.4665
# Epoch:43 | Iter:   20 | Time: 00:01:20 | Train Loss: 0.0253 | Average Loss: 0.4611
# Accuracy: 0.731771 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:01:21 | Train Loss: 0.0235 | Average Loss: 0.4565
# Epoch:44 | Iter:   20 | Time: 00:01:22 | Train Loss: 0.0156 | Average Loss: 0.4511
# Accuracy: 0.713542 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:01:22 | Train Loss: 0.0044 | Average Loss: 0.4467
# Epoch:45 | Iter:   20 | Time: 00:01:23 | Train Loss: 0.0435 | Average Loss: 0.4415
# Accuracy: 0.708333 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:01:24 | Train Loss: 0.1242 | Average Loss: 0.4373
# Epoch:46 | Iter:   20 | Time: 00:01:25 | Train Loss: 0.0025 | Average Loss: 0.4323
# Accuracy: 0.690104 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:01:26 | Train Loss: 0.0060 | Average Loss: 0.4285
# Epoch:47 | Iter:   20 | Time: 00:01:27 | Train Loss: 0.0739 | Average Loss: 0.4249
# Accuracy: 0.710938 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:01:28 | Train Loss: 0.0299 | Average Loss: 0.4214
# Epoch:48 | Iter:   20 | Time: 00:01:29 | Train Loss: 0.0530 | Average Loss: 0.4173
# Accuracy: 0.703125 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:01:30 | Train Loss: 0.0147 | Average Loss: 0.4136
# Epoch:49 | Iter:   20 | Time: 00:01:31 | Train Loss: 0.0099 | Average Loss: 0.4092
# Accuracy: 0.674479 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:01:32 | Train Loss: 0.0668 | Average Loss: 0.4063
# Epoch:50 | Iter:   20 | Time: 00:01:33 | Train Loss: 0.0246 | Average Loss: 0.4024
# Accuracy: 0.692708 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:01:34 | Train Loss: 0.0042 | Average Loss: 0.3991
# Epoch:51 | Iter:   20 | Time: 00:01:35 | Train Loss: 0.1696 | Average Loss: 0.3952
# Accuracy: 0.736979 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:01:36 | Train Loss: 0.0928 | Average Loss: 0.3921
# Epoch:52 | Iter:   20 | Time: 00:01:37 | Train Loss: 0.2430 | Average Loss: 0.3892
# Accuracy: 0.708333 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:01:38 | Train Loss: 0.1789 | Average Loss: 0.3869
# Epoch:53 | Iter:   20 | Time: 00:01:39 | Train Loss: 0.0488 | Average Loss: 0.3833
# Accuracy: 0.726562 | Time: 00:00:00
# Epoch:54 | Iter:    0 | Time: 00:01:39 | Train Loss: 0.0425 | Average Loss: 0.3804
# Epoch:54 | Iter:   20 | Time: 00:01:40 | Train Loss: 0.0127 | Average Loss: 0.3767
# Accuracy: 0.705729 | Time: 00:00:00
# Epoch:55 | Iter:    0 | Time: 00:01:41 | Train Loss: 0.0118 | Average Loss: 0.3737
# Epoch:55 | Iter:   20 | Time: 00:01:42 | Train Loss: 0.0035 | Average Loss: 0.3702
# Accuracy: 0.747396 | Time: 00:00:00
# Epoch:56 | Iter:    0 | Time: 00:01:43 | Train Loss: 0.0155 | Average Loss: 0.3672
# Epoch:56 | Iter:   20 | Time: 00:01:44 | Train Loss: 0.0018 | Average Loss: 0.3637
# Accuracy: 0.729167 | Time: 00:00:00
# Epoch:57 | Iter:    0 | Time: 00:01:45 | Train Loss: 0.0023 | Average Loss: 0.3607
# Epoch:57 | Iter:   20 | Time: 00:01:46 | Train Loss: 0.0008 | Average Loss: 0.3573
# Accuracy: 0.726562 | Time: 00:00:00
# Epoch:58 | Iter:    0 | Time: 00:01:47 | Train Loss: 0.0034 | Average Loss: 0.3545
# Epoch:58 | Iter:   20 | Time: 00:01:48 | Train Loss: 0.0054 | Average Loss: 0.3512
# Accuracy: 0.742188 | Time: 00:00:00
# Epoch:59 | Iter:    0 | Time: 00:01:49 | Train Loss: 0.0004 | Average Loss: 0.3484
# Epoch:59 | Iter:   20 | Time: 00:01:50 | Train Loss: 0.0006 | Average Loss: 0.3452
# Accuracy: 0.750000 | Time: 00:00:00
# Epoch:60 | Iter:    0 | Time: 00:01:51 | Train Loss: 0.0003 | Average Loss: 0.3425
# Epoch:60 | Iter:   20 | Time: 00:01:52 | Train Loss: 0.0004 | Average Loss: 0.3394
# Accuracy: 0.747396 | Time: 00:00:00
# Epoch:61 | Iter:    0 | Time: 00:01:53 | Train Loss: 0.0002 | Average Loss: 0.3368
# Epoch:61 | Iter:   20 | Time: 00:01:54 | Train Loss: 0.0005 | Average Loss: 0.3338
# Accuracy: 0.742188 | Time: 00:00:00
# Epoch:62 | Iter:    0 | Time: 00:01:55 | Train Loss: 0.0003 | Average Loss: 0.3313
# Epoch:62 | Iter:   20 | Time: 00:01:55 | Train Loss: 0.0003 | Average Loss: 0.3284
# Accuracy: 0.742188 | Time: 00:00:00
# Epoch:63 | Iter:    0 | Time: 00:01:56 | Train Loss: 0.0003 | Average Loss: 0.3260
# Epoch:63 | Iter:   20 | Time: 00:01:57 | Train Loss: 0.0002 | Average Loss: 0.3231
# Accuracy: 0.752604 | Time: 00:00:00
# Epoch:64 | Iter:    0 | Time: 00:01:58 | Train Loss: 0.0003 | Average Loss: 0.3208
# Epoch:64 | Iter:   20 | Time: 00:01:59 | Train Loss: 0.0002 | Average Loss: 0.3181
# Accuracy: 0.750000 | Time: 00:00:00
# Epoch:65 | Iter:    0 | Time: 00:02:00 | Train Loss: 0.0002 | Average Loss: 0.3158
# Epoch:65 | Iter:   20 | Time: 00:02:01 | Train Loss: 0.0002 | Average Loss: 0.3131
# Accuracy: 0.747396 | Time: 00:00:00
# Epoch:66 | Iter:    0 | Time: 00:02:02 | Train Loss: 0.0002 | Average Loss: 0.3109
# Epoch:66 | Iter:   20 | Time: 00:02:03 | Train Loss: 0.0002 | Average Loss: 0.3084
# Accuracy: 0.750000 | Time: 00:00:00
# Epoch:67 | Iter:    0 | Time: 00:02:04 | Train Loss: 0.0002 | Average Loss: 0.3062
# Epoch:67 | Iter:   20 | Time: 00:02:05 | Train Loss: 0.0002 | Average Loss: 0.3037
# Accuracy: 0.747396 | Time: 00:00:00
# Epoch:68 | Iter:    0 | Time: 00:02:06 | Train Loss: 0.0002 | Average Loss: 0.3016
# Epoch:68 | Iter:   20 | Time: 00:02:07 | Train Loss: 0.0002 | Average Loss: 0.2992
# Accuracy: 0.752604 | Time: 00:00:00
# Epoch:69 | Iter:    0 | Time: 00:02:08 | Train Loss: 0.0003 | Average Loss: 0.2972
# Epoch:69 | Iter:   20 | Time: 00:02:09 | Train Loss: 0.0002 | Average Loss: 0.2949
# Accuracy: 0.750000 | Time: 00:00:00
# Epoch:70 | Iter:    0 | Time: 00:02:10 | Train Loss: 0.0001 | Average Loss: 0.2929
# Epoch:70 | Iter:   20 | Time: 00:02:11 | Train Loss: 0.0002 | Average Loss: 0.2906
# Accuracy: 0.750000 | Time: 00:00:00
# Epoch:71 | Iter:    0 | Time: 00:02:11 | Train Loss: 0.0001 | Average Loss: 0.2887
# Epoch:71 | Iter:   20 | Time: 00:02:12 | Train Loss: 0.0001 | Average Loss: 0.2865
# Accuracy: 0.755208 | Time: 00:00:00
# Epoch:72 | Iter:    0 | Time: 00:02:13 | Train Loss: 0.0002 | Average Loss: 0.2847
# Epoch:72 | Iter:   20 | Time: 00:02:14 | Train Loss: 0.0001 | Average Loss: 0.2825
# Accuracy: 0.755208 | Time: 00:00:00
# Epoch:73 | Iter:    0 | Time: 00:02:15 | Train Loss: 0.0002 | Average Loss: 0.2807
# Epoch:73 | Iter:   20 | Time: 00:02:16 | Train Loss: 0.0001 | Average Loss: 0.2786
# Accuracy: 0.752604 | Time: 00:00:00
# Epoch:74 | Iter:    0 | Time: 00:02:17 | Train Loss: 0.0002 | Average Loss: 0.2769
# Epoch:74 | Iter:   20 | Time: 00:02:18 | Train Loss: 0.0001 | Average Loss: 0.2748
# Accuracy: 0.757812 | Time: 00:00:00
# Epoch:75 | Iter:    0 | Time: 00:02:19 | Train Loss: 0.0001 | Average Loss: 0.2731
# Epoch:75 | Iter:   20 | Time: 00:02:20 | Train Loss: 0.0001 | Average Loss: 0.2712
# Accuracy: 0.757812 | Time: 00:00:00
# Epoch:76 | Iter:    0 | Time: 00:02:21 | Train Loss: 0.0001 | Average Loss: 0.2695
# Epoch:76 | Iter:   20 | Time: 00:02:22 | Train Loss: 0.0001 | Average Loss: 0.2676
# Accuracy: 0.760417 | Time: 00:00:00
# Epoch:77 | Iter:    0 | Time: 00:02:23 | Train Loss: 0.0001 | Average Loss: 0.2660
# Epoch:77 | Iter:   20 | Time: 00:02:24 | Train Loss: 0.0001 | Average Loss: 0.2641
# Accuracy: 0.757812 | Time: 00:00:00
# Epoch:78 | Iter:    0 | Time: 00:02:25 | Train Loss: 0.0001 | Average Loss: 0.2625
# Epoch:78 | Iter:   20 | Time: 00:02:26 | Train Loss: 0.0001 | Average Loss: 0.2607
# Accuracy: 0.757812 | Time: 00:00:00
# Epoch:79 | Iter:    0 | Time: 00:02:27 | Train Loss: 0.0001 | Average Loss: 0.2591
# Epoch:79 | Iter:   20 | Time: 00:02:27 | Train Loss: 0.0001 | Average Loss: 0.2574
# Accuracy: 0.760417 | Time: 00:00:00
# Epoch:80 | Iter:    0 | Time: 00:02:28 | Train Loss: 0.0001 | Average Loss: 0.2559
# Epoch:80 | Iter:   20 | Time: 00:02:29 | Train Loss: 0.0001 | Average Loss: 0.2541
# Accuracy: 0.760417 | Time: 00:00:00
# Epoch:81 | Iter:    0 | Time: 00:02:30 | Train Loss: 0.0002 | Average Loss: 0.2527
# Epoch:81 | Iter:   20 | Time: 00:02:31 | Train Loss: 0.0001 | Average Loss: 0.2510
# Accuracy: 0.760417 | Time: 00:00:00
# Epoch:82 | Iter:    0 | Time: 00:02:32 | Train Loss: 0.0001 | Average Loss: 0.2495
# Epoch:82 | Iter:   20 | Time: 00:02:33 | Train Loss: 0.0001 | Average Loss: 0.2479
# Accuracy: 0.757812 | Time: 00:00:00
# Epoch:83 | Iter:    0 | Time: 00:02:34 | Train Loss: 0.0001 | Average Loss: 0.2465
# Epoch:83 | Iter:   20 | Time: 00:02:35 | Train Loss: 0.0001 | Average Loss: 0.2449
# Accuracy: 0.755208 | Time: 00:00:00
# Epoch:84 | Iter:    0 | Time: 00:02:36 | Train Loss: 0.0001 | Average Loss: 0.2435
# Epoch:84 | Iter:   20 | Time: 00:02:37 | Train Loss: 0.0001 | Average Loss: 0.2420
# Accuracy: 0.755208 | Time: 00:00:00
# Epoch:85 | Iter:    0 | Time: 00:02:38 | Train Loss: 0.0001 | Average Loss: 0.2406
# Epoch:85 | Iter:   20 | Time: 00:02:39 | Train Loss: 0.0001 | Average Loss: 0.2391
# Accuracy: 0.757812 | Time: 00:00:00
# Epoch:86 | Iter:    0 | Time: 00:02:40 | Train Loss: 0.0001 | Average Loss: 0.2378
# Epoch:86 | Iter:   20 | Time: 00:02:41 | Train Loss: 0.0001 | Average Loss: 0.2363
# Accuracy: 0.757812 | Time: 00:00:00
# Epoch:87 | Iter:    0 | Time: 00:02:42 | Train Loss: 0.0001 | Average Loss: 0.2350
# Epoch:87 | Iter:   20 | Time: 00:02:43 | Train Loss: 0.0001 | Average Loss: 0.2336
# Accuracy: 0.755208 | Time: 00:00:00
# Epoch:88 | Iter:    0 | Time: 00:02:43 | Train Loss: 0.0001 | Average Loss: 0.2323
# Epoch:88 | Iter:   20 | Time: 00:02:44 | Train Loss: 0.0001 | Average Loss: 0.2309
# Accuracy: 0.760417 | Time: 00:00:00
# Epoch:89 | Iter:    0 | Time: 00:02:45 | Train Loss: 0.0001 | Average Loss: 0.2297
# Epoch:89 | Iter:   20 | Time: 00:02:46 | Train Loss: 0.0001 | Average Loss: 0.2283
# Accuracy: 0.757812 | Time: 00:00:00
# Epoch:90 | Iter:    0 | Time: 00:02:47 | Train Loss: 0.0001 | Average Loss: 0.2271
# Epoch:90 | Iter:   20 | Time: 00:02:48 | Train Loss: 0.0001 | Average Loss: 0.2258
# Accuracy: 0.755208 | Time: 00:00:00
# Epoch:91 | Iter:    0 | Time: 00:02:49 | Train Loss: 0.0001 | Average Loss: 0.2246
# Epoch:91 | Iter:   20 | Time: 00:02:50 | Train Loss: 0.0001 | Average Loss: 0.2233
# Accuracy: 0.760417 | Time: 00:00:00
# Epoch:92 | Iter:    0 | Time: 00:02:51 | Train Loss: 0.0001 | Average Loss: 0.2221
# Epoch:92 | Iter:   20 | Time: 00:02:52 | Train Loss: 0.0001 | Average Loss: 0.2208
# Accuracy: 0.757812 | Time: 00:00:00
# Epoch:93 | Iter:    0 | Time: 00:02:53 | Train Loss: 0.0001 | Average Loss: 0.2197
# Epoch:93 | Iter:   20 | Time: 00:02:54 | Train Loss: 0.0001 | Average Loss: 0.2184
# Accuracy: 0.760417 | Time: 00:00:00
# Epoch:94 | Iter:    0 | Time: 00:02:55 | Train Loss: 0.0001 | Average Loss: 0.2174
# Epoch:94 | Iter:   20 | Time: 00:02:56 | Train Loss: 0.0001 | Average Loss: 0.2161
# Accuracy: 0.760417 | Time: 00:00:00
# Epoch:95 | Iter:    0 | Time: 00:02:57 | Train Loss: 0.0001 | Average Loss: 0.2151
# Epoch:95 | Iter:   20 | Time: 00:02:58 | Train Loss: 0.0001 | Average Loss: 0.2138
# Accuracy: 0.755208 | Time: 00:00:00
# Epoch:96 | Iter:    0 | Time: 00:02:59 | Train Loss: 0.0001 | Average Loss: 0.2128
# Epoch:96 | Iter:   20 | Time: 00:03:00 | Train Loss: 0.0001 | Average Loss: 0.2116
# Accuracy: 0.757812 | Time: 00:00:00
# Epoch:97 | Iter:    0 | Time: 00:03:00 | Train Loss: 0.0001 | Average Loss: 0.2106
# Epoch:97 | Iter:   20 | Time: 00:03:01 | Train Loss: 0.0001 | Average Loss: 0.2094
# Accuracy: 0.755208 | Time: 00:00:00
# Epoch:98 | Iter:    0 | Time: 00:03:02 | Train Loss: 0.0001 | Average Loss: 0.2084
# Epoch:98 | Iter:   20 | Time: 00:03:03 | Train Loss: 0.0001 | Average Loss: 0.2073
# Accuracy: 0.752604 | Time: 00:00:00
# Epoch:99 | Iter:    0 | Time: 00:03:04 | Train Loss: 0.0001 | Average Loss: 0.2063
# Epoch:99 | Iter:   20 | Time: 00:03:05 | Train Loss: 0.0001 | Average Loss: 0.2052
# Accuracy: 0.752604 | Time: 00:00:00
# Epoch:100 | Iter:    0 | Time: 00:03:06 | Train Loss: 0.0001 | Average Loss: 0.2042
# Epoch:100 | Iter:   20 | Time: 00:03:07 | Train Loss: 0.0000 | Average Loss: 0.2031
# Accuracy: 0.757812 | Time: 00:00:00
# Epoch:101 | Iter:    0 | Time: 00:03:08 | Train Loss: 0.0000 | Average Loss: 0.2022
# Epoch:101 | Iter:   20 | Time: 00:03:09 | Train Loss: 0.0000 | Average Loss: 0.2011
# Accuracy: 0.755208 | Time: 00:00:00
# Epoch:102 | Iter:    0 | Time: 00:03:10 | Train Loss: 0.0000 | Average Loss: 0.2002
# Epoch:102 | Iter:   20 | Time: 00:03:11 | Train Loss: 0.0000 | Average Loss: 0.1991
# Accuracy: 0.757812 | Time: 00:00:00
# Epoch:103 | Iter:    0 | Time: 00:03:12 | Train Loss: 0.0000 | Average Loss: 0.1982
# Epoch:103 | Iter:   20 | Time: 00:03:13 | Train Loss: 0.0001 | Average Loss: 0.1972
# Accuracy: 0.752604 | Time: 00:00:00
# Epoch:104 | Iter:    0 | Time: 00:03:14 | Train Loss: 0.0001 | Average Loss: 0.1963
# Epoch:104 | Iter:   20 | Time: 00:03:15 | Train Loss: 0.0000 | Average Loss: 0.1952
# Accuracy: 0.755208 | Time: 00:00:00
# Epoch:105 | Iter:    0 | Time: 00:03:16 | Train Loss: 0.0000 | Average Loss: 0.1944
# Epoch:105 | Iter:   20 | Time: 00:03:16 | Train Loss: 0.0000 | Average Loss: 0.1934
# Accuracy: 0.752604 | Time: 00:00:00
# Epoch:106 | Iter:    0 | Time: 00:03:17 | Train Loss: 0.0000 | Average Loss: 0.1925
# Epoch:106 | Iter:   20 | Time: 00:03:18 | Train Loss: 0.0000 | Average Loss: 0.1916
# Accuracy: 0.757812 | Time: 00:00:00
# Epoch:107 | Iter:    0 | Time: 00:03:19 | Train Loss: 0.0000 | Average Loss: 0.1907
# Epoch:107 | Iter:   20 | Time: 00:03:20 | Train Loss: 0.0000 | Average Loss: 0.1898
# Accuracy: 0.755208 | Time: 00:00:00
# Epoch:108 | Iter:    0 | Time: 00:03:21 | Train Loss: 0.0000 | Average Loss: 0.1889
# Epoch:108 | Iter:   20 | Time: 00:03:22 | Train Loss: 0.0000 | Average Loss: 0.1880
# Accuracy: 0.750000 | Time: 00:00:00
# Epoch:109 | Iter:    0 | Time: 00:03:23 | Train Loss: 0.0000 | Average Loss: 0.1872
# Epoch:109 | Iter:   20 | Time: 00:03:24 | Train Loss: 0.0001 | Average Loss: 0.1863
# Accuracy: 0.750000 | Time: 00:00:00
# Epoch:110 | Iter:    0 | Time: 00:03:25 | Train Loss: 0.0000 | Average Loss: 0.1855
# Epoch:110 | Iter:   20 | Time: 00:03:26 | Train Loss: 0.0000 | Average Loss: 0.1846
# Accuracy: 0.747396 | Time: 00:00:00
# Epoch:111 | Iter:    0 | Time: 00:03:27 | Train Loss: 0.0000 | Average Loss: 0.1838
# Epoch:111 | Iter:   20 | Time: 00:03:28 | Train Loss: 0.0001 | Average Loss: 0.1829
# Accuracy: 0.747396 | Time: 00:00:00
# Epoch:112 | Iter:    0 | Time: 00:03:29 | Train Loss: 0.0000 | Average Loss: 0.1821
# Epoch:112 | Iter:   20 | Time: 00:03:30 | Train Loss: 0.0000 | Average Loss: 0.1813
# Accuracy: 0.747396 | Time: 00:00:00
# Epoch:113 | Iter:    0 | Time: 00:03:31 | Train Loss: 0.0000 | Average Loss: 0.1805
# Epoch:113 | Iter:   20 | Time: 00:03:32 | Train Loss: 0.0000 | Average Loss: 0.1796
# Accuracy: 0.752604 | Time: 00:00:00
# Epoch:114 | Iter:    0 | Time: 00:03:32 | Train Loss: 0.0000 | Average Loss: 0.1789
# Epoch:114 | Iter:   20 | Time: 00:03:33 | Train Loss: 0.0000 | Average Loss: 0.1781
# Accuracy: 0.755208 | Time: 00:00:00
# Epoch:115 | Iter:    0 | Time: 00:03:34 | Train Loss: 0.0000 | Average Loss: 0.1773
# Epoch:115 | Iter:   20 | Time: 00:03:35 | Train Loss: 0.0000 | Average Loss: 0.1765
# Accuracy: 0.752604 | Time: 00:00:00
# Epoch:116 | Iter:    0 | Time: 00:03:36 | Train Loss: 0.0000 | Average Loss: 0.1758
# Epoch:116 | Iter:   20 | Time: 00:03:37 | Train Loss: 0.0000 | Average Loss: 0.1750
# Accuracy: 0.752604 | Time: 00:00:00
# Epoch:117 | Iter:    0 | Time: 00:03:38 | Train Loss: 0.0000 | Average Loss: 0.1743
# Epoch:117 | Iter:   20 | Time: 00:03:39 | Train Loss: 0.0000 | Average Loss: 0.1735
# Accuracy: 0.752604 | Time: 00:00:00
# Epoch:118 | Iter:    0 | Time: 00:03:40 | Train Loss: 0.0000 | Average Loss: 0.1728
# Epoch:118 | Iter:   20 | Time: 00:03:41 | Train Loss: 0.0000 | Average Loss: 0.1720
# Accuracy: 0.752604 | Time: 00:00:00
# Epoch:119 | Iter:    0 | Time: 00:03:42 | Train Loss: 0.0000 | Average Loss: 0.1713
# Epoch:119 | Iter:   20 | Time: 00:03:43 | Train Loss: 0.0000 | Average Loss: 0.1706
# Accuracy: 0.750000 | Time: 00:00:00
# Epoch:120 | Iter:    0 | Time: 00:03:44 | Train Loss: 0.0000 | Average Loss: 0.1699
# Epoch:120 | Iter:   20 | Time: 00:03:45 | Train Loss: 0.0000 | Average Loss: 0.1691
# Accuracy: 0.755208 | Time: 00:00:00

# %% [markdown]
# **Answer**:
#
# (1) which layers of AlexNet have been replaced - Classifier Layers 3,4,6.
#
#
#
# (2) the architecture of the new layers added including activation methods (same as problem 1)
#
# Data augmentation: Rotated images by 180 degrees.
#
# Data normalization: Made mean equal to zero. Implemented in load_dataset() funciton
#
# Features Layers : None
#
# Classifier Layer 3: Now a Sigmoid()
#
# Classifier Layer 4: Linear Layer with input size 4096, and output size 1000.
#
# Classifier Layer 6: Linear Layer with input size 1000, and output size 16.
#
#
# (3) the final accuracy on test set
#
# Accuracy on test set: 0.755208

# %% [markdown]
# ### Problem 2.2
# **Strategy B**: One could use those 1000 activations as a feature in place of a hand crafted feature such as a bag-of-features representation. You would train a classifier (typically a linear SVM) in that 1000 dimensional feature space. However, those activations are clearly very object specific and may not generalize well to new recognition tasks. It is generally better to use the activations in slightly earlier layers of the network, e.g. the 4096 activations in the last 2nd fully-connected layer. You can often get away with sub-sampling those 4096 activations considerably, e.g. taking only the first 1000 activations.
#
# (25 points) Implement Strategy B where you use the activations of the pre-trained **AlexNet** as features to train **one-vs-all SVMs** for your scene classification task. Report the final accuracy on test set. You should be able to achieve accuracy of **0.80** approximately. The minimum accuracy required for this section is **0.70**.

# %%
#--------------------------------------------------
#       Get Features from AlexNet
#--------------------------------------------------
from torch.autograd import Variable
model = torch.hub.load('pytorch/vision:v0.9.0', 'alexnet', pretrained=True)
#to get 4096 activations
new_classifier = nn.Sequential(*list(model.classifier.children())[:-1])
model.classifier = new_classifier

epoch = 120
train_option = {}
train_option['lr'] = 0.001
train_option['epoch'] = 30
train_option['device'] = 'gpu'

#get train features and train output
train_feat = []
train_label = []
loss_func = nn.CrossEntropyLoss()
for ep in range(0,30):
  #print(range(epoch))
  print(epoch)
  optimizer = optim.Adam(model.parameters(), lr=.001)
  model.train()
  iters = 0
  running_loss = 0.0

  for iter, (x, y) in enumerate(trainloader_large):
    iters +=1
    batch_x = Variable(x).float()
    batch_y = Variable(y).long()

    outputs = model(batch_x)
    loss = loss_func(outputs, batch_y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if(ep == 29):
      for i in range(0,len(batch_y)):
        train_label.append(batch_y[i])
      for i in range(0,len(outputs)):
        train_feat.append(outputs[i][0:1000])

#get test features and test output
model.eval()
acc = 0.0
count = 0
test_feat = []
test_label = []
for iter, (x, y) in enumerate(testloader_large):
      count += x.shape[0]
      batch_x = Variable(x).float()
      batch_y = Variable(y).long()

      outputs = model(batch_x)
      for i in range(0,len(batch_y)):
        test_label.append(batch_y[i])
      for i in range(0,len(outputs)):
        test_feat.append(outputs[i][0:1000])

      acc += torch.sum(outputs.max(1)[1]==batch_y)
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.9.0
# 120
# 120
# 120
# 120
# 120

# %%
#--------------------------------------------------
#       Train and Evaluate SVM
#--------------------------------------------------
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn import metrics

for i in range(0,len(train_feat)):
  if(type(train_feat[i])!=list):
    train_feat[i] = train_feat[i].tolist()

for i in range(0,len(test_feat)):
  if(type(test_feat[i])!=list):
    test_feat[i] = test_feat[i].tolist()
clf = OneVsRestClassifier(SVC()).fit(train_feat, train_label)
y_pred = clf.predict(np.array(test_feat))
accur = sklearn.metrics.accuracy_score(test_label, y_pred)
print("Accuracy: " + str(accur))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 0 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 1 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 2 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 3 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 4 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 5 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 6 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 7 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 8 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 9 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 10 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 11 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 12 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 13 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 14 is present in all training examples.
#   str(classes[c]))
# /usr/local/lib/python3.7/dist-packages/sklearn/multiclass.py:75: UserWarning: Label not 15 is present in all training examples.
#   str(classes[c]))
# Accuracy: 0.0

# %% [markdown]
# **Answer**:
#
# Accuracy on test set: 0.0

# %% [markdown]
# ### Problem 2.3 (Bonus)
#
# (Bonus: 10 points) Bonus will be given to those who fine-tune the [ResNet network](https://pytorch.org/docs/stable/_modules/torchvision/models/resnet.html) [(paper)](https://arxiv.org/abs/1512.03385) and compare performance with AlexNet. Explain why ResNet performed better or worse. You are **required** to use **resnet50** model. You should be able to achieve accuracy of **0.99** approximately. The minimum accuracy required for this section is **0.85**.

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
import torch
torch.cuda.empty_cache()

model = torch.hub.load('pytorch/vision:v0.9.0', 'resnet50', pretrained=True)
new_classifier = nn.Sequential(
    #nn.BatchNorm4d(2048),
    nn.Linear(in_features = 2048, out_features = 1000, bias = True),
    #nn.BatchNorm2d(1000),
    #nn.ReLU(),
    nn.Tanh(),
    nn.Dropout(.5),
    nn.Linear(in_features = 1000, out_features = 500, bias = True),
    #nn.ReLU(),
    nn.Tanh(),
    #nn.Dropout(.5),
    nn.Linear(in_features = 500, out_features = 200, bias = True),
    nn.Tanh(),
    #nn.ReLU(),
    #nn.Dropout(.5),
    nn.Linear(in_features = 200, out_features = 100, bias = True),
    nn.Tanh(),
    #nn.ReLU(),
    #nn.Dropout(.5),
    nn.Linear(in_features = 100, out_features = 50, bias = True),
    nn.Tanh(),
    #nn.ReLU(),
    nn.Linear(in_features = 50, out_features = 16, bias = True))
model.fc = new_classifier


train_option = {}
train_option['lr'] = 0.002
train_option['epoch'] = 120
train_option['device'] = 'gpu'
trainModel(model, trainloader_large, train_option, testloader_large)
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.9.0
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7772 | Average Loss: 2.7772
# Epoch: 1 | Iter:   20 | Time: 00:00:07 | Train Loss: 2.5706 | Average Loss: 2.7144
# Accuracy: 0.065104 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:14 | Train Loss: 2.3462 | Average Loss: 2.5820
# Epoch: 2 | Iter:   20 | Time: 00:00:22 | Train Loss: 1.9846 | Average Loss: 2.4541
# Accuracy: 0.187500 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:29 | Train Loss: 2.0450 | Average Loss: 2.3872
# Epoch: 3 | Iter:   20 | Time: 00:00:36 | Train Loss: 2.0650 | Average Loss: 2.3338
# Accuracy: 0.169271 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:43 | Train Loss: 2.0669 | Average Loss: 2.2943
# Epoch: 4 | Iter:   20 | Time: 00:00:51 | Train Loss: 1.9078 | Average Loss: 2.2537
# Accuracy: 0.161458 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:58 | Train Loss: 1.8825 | Average Loss: 2.2212
# Epoch: 5 | Iter:   20 | Time: 00:01:05 | Train Loss: 1.9346 | Average Loss: 2.1951
# Accuracy: 0.229167 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:01:12 | Train Loss: 1.9849 | Average Loss: 2.1734
# Epoch: 6 | Iter:   20 | Time: 00:01:20 | Train Loss: 1.9868 | Average Loss: 2.1566
# Accuracy: 0.216146 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:01:27 | Train Loss: 1.8939 | Average Loss: 2.1392
# Epoch: 7 | Iter:   20 | Time: 00:01:34 | Train Loss: 1.9985 | Average Loss: 2.1259
# Accuracy: 0.216146 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:01:41 | Train Loss: 2.2131 | Average Loss: 2.1150
# Epoch: 8 | Iter:   20 | Time: 00:01:49 | Train Loss: 1.9044 | Average Loss: 2.1042
# Accuracy: 0.083333 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:01:56 | Train Loss: 1.9780 | Average Loss: 2.0981
# Epoch: 9 | Iter:   20 | Time: 00:02:03 | Train Loss: 1.8791 | Average Loss: 2.0921
# Accuracy: 0.257812 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:02:10 | Train Loss: 1.9680 | Average Loss: 2.0863
# Epoch:10 | Iter:   20 | Time: 00:02:18 | Train Loss: 1.9207 | Average Loss: 2.0758
# Accuracy: 0.161458 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:02:25 | Train Loss: 2.1554 | Average Loss: 2.0683
# Epoch:11 | Iter:   20 | Time: 00:02:32 | Train Loss: 1.9000 | Average Loss: 2.0601
# Accuracy: 0.148438 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:02:39 | Train Loss: 1.9050 | Average Loss: 2.0512
# Epoch:12 | Iter:   20 | Time: 00:02:47 | Train Loss: 1.8426 | Average Loss: 2.0418
# Accuracy: 0.187500 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:02:54 | Train Loss: 2.1377 | Average Loss: 2.0351
# Epoch:13 | Iter:   20 | Time: 00:03:01 | Train Loss: 1.7285 | Average Loss: 2.0262
# Accuracy: 0.239583 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:03:08 | Train Loss: 1.9400 | Average Loss: 2.0175
# Epoch:14 | Iter:   20 | Time: 00:03:16 | Train Loss: 1.7293 | Average Loss: 2.0087
# Accuracy: 0.281250 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:03:23 | Train Loss: 1.8677 | Average Loss: 2.0009
# Epoch:15 | Iter:   20 | Time: 00:03:30 | Train Loss: 1.6633 | Average Loss: 1.9928
# Accuracy: 0.281250 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:03:37 | Train Loss: 1.8359 | Average Loss: 1.9856
# Epoch:16 | Iter:   20 | Time: 00:03:45 | Train Loss: 1.6350 | Average Loss: 1.9775
# Accuracy: 0.302083 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:03:52 | Train Loss: 1.8949 | Average Loss: 1.9692
# Epoch:17 | Iter:   20 | Time: 00:03:59 | Train Loss: 1.5690 | Average Loss: 1.9616
# Accuracy: 0.234375 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:04:06 | Train Loss: 1.9027 | Average Loss: 1.9553
# Epoch:18 | Iter:   20 | Time: 00:04:14 | Train Loss: 1.6564 | Average Loss: 1.9496
# Accuracy: 0.171875 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:04:21 | Train Loss: 1.7198 | Average Loss: 1.9435
# Epoch:19 | Iter:   20 | Time: 00:04:28 | Train Loss: 1.6072 | Average Loss: 1.9382
# Accuracy: 0.260417 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:04:35 | Train Loss: 1.7997 | Average Loss: 1.9328
# Epoch:20 | Iter:   20 | Time: 00:04:43 | Train Loss: 1.7314 | Average Loss: 1.9264
# Accuracy: 0.291667 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:04:50 | Train Loss: 1.7734 | Average Loss: 1.9207
# Epoch:21 | Iter:   20 | Time: 00:04:57 | Train Loss: 1.5980 | Average Loss: 1.9160
# Accuracy: 0.283854 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:05:04 | Train Loss: 1.8328 | Average Loss: 1.9102
# Epoch:22 | Iter:   20 | Time: 00:05:12 | Train Loss: 1.6935 | Average Loss: 1.9045
# Accuracy: 0.213542 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:05:19 | Train Loss: 1.7352 | Average Loss: 1.8994
# Epoch:23 | Iter:   20 | Time: 00:05:26 | Train Loss: 1.6147 | Average Loss: 1.8956
# Accuracy: 0.333333 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:05:33 | Train Loss: 1.6662 | Average Loss: 1.8909
# Epoch:24 | Iter:   20 | Time: 00:05:41 | Train Loss: 1.4600 | Average Loss: 1.8851
# Accuracy: 0.229167 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:05:48 | Train Loss: 1.8682 | Average Loss: 1.8801
# Epoch:25 | Iter:   20 | Time: 00:05:55 | Train Loss: 1.4519 | Average Loss: 1.8763
# Accuracy: 0.341146 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:06:02 | Train Loss: 1.7114 | Average Loss: 1.8725
# Epoch:26 | Iter:   20 | Time: 00:06:10 | Train Loss: 1.5579 | Average Loss: 1.8678
# Accuracy: 0.291667 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:06:17 | Train Loss: 1.6090 | Average Loss: 1.8644
# Epoch:27 | Iter:   20 | Time: 00:06:24 | Train Loss: 1.5131 | Average Loss: 1.8609
# Accuracy: 0.296875 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:06:31 | Train Loss: 1.5654 | Average Loss: 1.8569
# Epoch:28 | Iter:   20 | Time: 00:06:39 | Train Loss: 1.5542 | Average Loss: 1.8538
# Accuracy: 0.268229 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:06:46 | Train Loss: 1.6902 | Average Loss: 1.8506
# Epoch:29 | Iter:   20 | Time: 00:06:53 | Train Loss: 1.7463 | Average Loss: 1.8465
# Accuracy: 0.333333 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:07:00 | Train Loss: 1.6350 | Average Loss: 1.8430
# Epoch:30 | Iter:   20 | Time: 00:07:08 | Train Loss: 1.5163 | Average Loss: 1.8394
# Accuracy: 0.333333 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:07:15 | Train Loss: 1.7675 | Average Loss: 1.8356
# Epoch:31 | Iter:   20 | Time: 00:07:22 | Train Loss: 1.5470 | Average Loss: 1.8321
# Accuracy: 0.328125 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:07:29 | Train Loss: 1.7635 | Average Loss: 1.8295
# Epoch:32 | Iter:   20 | Time: 00:07:37 | Train Loss: 1.4824 | Average Loss: 1.8270
# Accuracy: 0.247396 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:07:44 | Train Loss: 1.7773 | Average Loss: 1.8244
# Epoch:33 | Iter:   20 | Time: 00:07:51 | Train Loss: 1.4276 | Average Loss: 1.8211
# Accuracy: 0.359375 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:07:58 | Train Loss: 1.7597 | Average Loss: 1.8178
# Epoch:34 | Iter:   20 | Time: 00:08:06 | Train Loss: 1.4783 | Average Loss: 1.8140
# Accuracy: 0.333333 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:08:13 | Train Loss: 1.7269 | Average Loss: 1.8112
# Epoch:35 | Iter:   20 | Time: 00:08:20 | Train Loss: 1.5469 | Average Loss: 1.8078
# Accuracy: 0.268229 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:08:27 | Train Loss: 1.6511 | Average Loss: 1.8054
# Epoch:36 | Iter:   20 | Time: 00:08:35 | Train Loss: 1.5009 | Average Loss: 1.8016
# Accuracy: 0.263021 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:08:42 | Train Loss: 1.5241 | Average Loss: 1.7984
# Epoch:37 | Iter:   20 | Time: 00:08:49 | Train Loss: 1.5731 | Average Loss: 1.7948
# Accuracy: 0.294271 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:08:56 | Train Loss: 1.6423 | Average Loss: 1.7922
# Epoch:38 | Iter:   20 | Time: 00:09:04 | Train Loss: 1.4168 | Average Loss: 1.7883
# Accuracy: 0.364583 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:09:11 | Train Loss: 1.8002 | Average Loss: 1.7855
# Epoch:39 | Iter:   20 | Time: 00:09:18 | Train Loss: 1.4780 | Average Loss: 1.7830
# Accuracy: 0.359375 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:09:25 | Train Loss: 1.5922 | Average Loss: 1.7801
# Epoch:40 | Iter:   20 | Time: 00:09:33 | Train Loss: 1.4059 | Average Loss: 1.7766
# Accuracy: 0.335938 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:09:40 | Train Loss: 1.6127 | Average Loss: 1.7741
# Epoch:41 | Iter:   20 | Time: 00:09:47 | Train Loss: 1.5075 | Average Loss: 1.7713
# Accuracy: 0.299479 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:09:54 | Train Loss: 1.7721 | Average Loss: 1.7694
# Epoch:42 | Iter:   20 | Time: 00:10:02 | Train Loss: 1.3255 | Average Loss: 1.7667
# Accuracy: 0.346354 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:10:09 | Train Loss: 1.6233 | Average Loss: 1.7640
# Epoch:43 | Iter:   20 | Time: 00:10:16 | Train Loss: 1.3809 | Average Loss: 1.7602
# Accuracy: 0.385417 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:10:23 | Train Loss: 1.4974 | Average Loss: 1.7577
# Epoch:44 | Iter:   20 | Time: 00:10:31 | Train Loss: 1.3591 | Average Loss: 1.7547
# Accuracy: 0.375000 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:10:38 | Train Loss: 1.4531 | Average Loss: 1.7518
# Epoch:45 | Iter:   20 | Time: 00:10:45 | Train Loss: 1.4765 | Average Loss: 1.7488
# Accuracy: 0.132812 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:10:52 | Train Loss: 1.4957 | Average Loss: 1.7466
# Epoch:46 | Iter:   20 | Time: 00:11:00 | Train Loss: 1.3382 | Average Loss: 1.7434
# Accuracy: 0.242188 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:11:07 | Train Loss: 1.6660 | Average Loss: 1.7415
# Epoch:47 | Iter:   20 | Time: 00:11:14 | Train Loss: 1.6708 | Average Loss: 1.7396
# Accuracy: 0.330729 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:11:21 | Train Loss: 1.6813 | Average Loss: 1.7388
# Epoch:48 | Iter:   20 | Time: 00:11:29 | Train Loss: 1.4786 | Average Loss: 1.7369
# Accuracy: 0.354167 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:11:36 | Train Loss: 1.5596 | Average Loss: 1.7355
# Epoch:49 | Iter:   20 | Time: 00:11:43 | Train Loss: 1.5278 | Average Loss: 1.7333
# Accuracy: 0.236979 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:11:50 | Train Loss: 2.2671 | Average Loss: 1.7336
# Epoch:50 | Iter:   20 | Time: 00:11:58 | Train Loss: 1.6234 | Average Loss: 1.7354
# Accuracy: 0.236979 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:12:05 | Train Loss: 1.8085 | Average Loss: 1.7363
# Epoch:51 | Iter:   20 | Time: 00:12:12 | Train Loss: 1.6680 | Average Loss: 1.7349
# Accuracy: 0.283854 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:12:19 | Train Loss: 1.5411 | Average Loss: 1.7334
# Epoch:52 | Iter:   20 | Time: 00:12:27 | Train Loss: 1.6713 | Average Loss: 1.7320
# Accuracy: 0.283854 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:12:34 | Train Loss: 1.7857 | Average Loss: 1.7307
# Epoch:53 | Iter:   20 | Time: 00:12:41 | Train Loss: 1.3163 | Average Loss: 1.7290
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-b563ddabae9f> in <module>()
#      36 train_option['epoch'] = 120
#      37 train_option['device'] = 'gpu'
# ---> 38 trainModel(model, trainloader_large, train_option, testloader_large)
#
# <ipython-input-6-a6dbef4aaecf> in trainModel(net, trainloader, train_option, testloader)
#      40       optimizer.zero_grad()
#      41       loss.backward()
# ---> 42       optimizer.step()
#      43       running_loss += loss.item()
#      44
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      87                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      88                 with torch.autograd.profiler.record_function(profile_name):
# ---> 89                     return func(*args, **kwargs)
#      90             return wrapper
#      91
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/adam.py in step(self, closure)
#     117                    group['lr'],
#     118                    group['weight_decay'],
# --> 119                    group['eps'])
#     120         return loss
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      90             denom = (max_exp_avg_sqs[i].sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      91         else:
# ---> 92             denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      93
#      94         step_size = lr / bias_correction1
#
# KeyboardInterrupt:

# %% [markdown]
# **Answer**:
#
# Accuracy on test set:
#
# Resnet performs better because it uses residules to maximize accuracy.

# %% [markdown]
# ## Submission guidelines
# ---
# Extract the downloaded .zip file to a folder of your preference. The input and output paths are predefined and **DO NOT** change them, (we assume that 'Surname_Givenname_SBUID_hw4' is your working directory, and all the paths are relative to this directory).  The image read and write functions are already written for you. All you need to do is to fill in the blanks as indicated to generate proper outputs. **DO NOT** zip and upload the dataset on blackboard due to size limit.
#
# When submitting your .zip file through blackboard, please
# -- name your .zip file as **Surname_Givenname_SBUID_hw*.zip**.
#
# This zip file should include:
# ```
# Surname_Givenname_SBUID_hw*
#         |---Surname_Givenname_SBUID_hw*.ipynb
#         |---Surname_Givenname_SBUID_hw*.pdf
# ```
#
# For instance, student Yann LeCun should submit a zip file named "LeCun_Yann_111134567_hw4.zip" for homework4 in this structure:
# ```
# LeCun_Yann_111134567_hw4
#         |---LeCun_Yann_111134567_hw4.ipynb
#         |---LeCun_Yann_111134567_hw4.pdf
# ```
#
# The **Surname_Givenname_SBUID_hw*.pdf** should include a **google shared link**. To generate the **google shared link**, first create a folder named **Surname_Givenname_SBUID_hw*** in your Google Drive with your Stony Brook account. The structure of the files in the folder should be exactly the same as the one you downloaded. If you alter the folder structures, the grading of your homework will be significantly delayed and possibly penalized.
#
# Then right click this folder, click ***Get shareable link***, in the People textfield, enter TA's emails. Make sure that TAs who have the link **can edit**, ***not just*** **can view**, and also **uncheck** the **Notify people** box.
#
# Colab has a good feature of version control, you should take advantage of this to save your work properly. However, the timestamp of the submission made in blackboard is the only one that we consider for grading. To be more specific, we will only grade the version of your code right before the timestamp of the submission made in blackboard.
#
# You are encouraged to post and answer questions on Piazza. Based on the amount of email that we have received in past years, there might be dealys in replying to personal emails. Please ask questions on Piazza and send emails only for personal issues.
#
# Be aware that your code will undergo plagiarism check both vertically and horizontally. Please do your own work.
#
# **Late submission penalty:** <br>
# There will be a 10% penalty per day for late submission. However, you will have 4 days throughout the whole semester to submit late without penalty. Note that the grace period is calculated by days instead of hours. If you submit the homework one minute after the deadline, one late day will be counted. Likewise, if you submit one minute after the deadline, the 10% penaly will be imposed if not using the grace period.

# %% [markdown]
# <!--Write your report here in markdown or html-->
